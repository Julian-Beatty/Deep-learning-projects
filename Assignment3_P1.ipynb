# %% [markdown]
# # Assignment 3 Image Segmentation
# In this assignment, you will train a dense predictor to conduct semantic segmentation of building components on the QuakeCity dataset developed at SAIL-UH. The dataset consists of synthetic CGI images of earthquake damaged buildings https://sail.cive.uh.edu/quakecity/. The dataset has 8 different classes which can appear in any given image. Your model will predict whether any of the classes is present in each pixel.

# %%
#do not import any aditional packages
import sys
import os
import numpy as np
import torch
import matplotlib
from matplotlib import pyplot as plt
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from PIL import Image
from torchvision import transforms
import torchvision.transforms.functional as F
import time
import torch
import torch.nn as nn
import random
import torch.nn.functional as nnF

# %% [markdown]
# Edit the below cell if you are using Colab for this assignment, and to enter the path to the dataset

# %%
from google.colab import drive #comment out this line if you are using Colab
drive.mount('/content/gdrive') #comment out this line if you are using Colab
#############################################################################
# TODO: Edit the path to your assignment folder                             #
#############################################################################
main_path = "/content/gdrive/My Drive/CIVE 6358/Assignment 3"
os.chdir(main_path)
#############################################################################

#do not edit this line
from component2kaggle import component2kagglefn
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# The cell below is used to create a Pandas dataframe of image names. Do not edit this cell

# %%
# paths to csv files containing file names for each set of images
train_csv_path = os.path.join(main_path,"split_train.csv")
val_csv_path = os.path.join(main_path,"split_val.csv")
test_csv_path = os.path.join(main_path,"test.csv")

# path to labels and images
data_path = os.path.join(main_path,"dataset")
image_path = os.path.join(data_path,"image")
label_path = os.path.join(data_path,"label")

# define pandas dataframes
train_df = pd.read_csv(train_csv_path,header = None,index_col = None,delimiter=',')
val_df = pd.read_csv(val_csv_path,header = None,index_col = None,delimiter=',')
test_df = pd.read_csv(test_csv_path,header = None,index_col = None,delimiter=',')

# %% [markdown]
# If you imported your data correctly, a sample image from the dataset should show after running the cell below together with it's corresponding label

# %%
rand_img_name = train_df.sample().values[0][0]
test_img = Image.open(os.path.join(image_path,rand_img_name))
plt.imshow(test_img)

# %%
# load a label image from the train data frame
component_img = Image.open(os.path.join(label_path,rand_img_name))
plt.imshow(component_img)

# %% [markdown]
# Each image has 8 possible classes. The classes in the dataset are listed below with the 8 colors assigned provided in parenthesis.
#
# * 0 - wall - (202,150,150) (pink)
# * 1 - beam - (198,186,100) (dark yellow)
# * 2 - column - (167,183,186) (gray blue)
# * 3 - window frame - (255,255,133) (yellow)
# * 4 - window pane - (192,192,206) (purple gray blue)
# * 5 - balcony - (32,80,160) (blue)
# * 6 - slab - (193,134,1) (burnt orange)
# * 100 - ignore - (70,70,70) (deep brown)

# %% [markdown]
# <br>The Following function is used to one hot encode an array of labels. Remember as this is a dense prediction problem, the output and input have the same size, but the output in this case is a single channel image of size 480x270.  As there are 8 classes, the dimensions of the one hot encoding should be (8x480x270)
# * the input of this function is an array containing labels 0,1,2,3,4,5,6,100
# * map 0,1,2,3,4,5,6 to channel 0,1,2,3,4,5,6
# * map 100 to channel 7

# %%
#one hot encode labels
def label_to_nparray(seg):
    channels = 8
    seg_0 = seg.shape[0]
    seg_1 = seg.shape[1]
    nparray = np.zeros([channels, seg_0, seg_1], dtype=np.uint8)
    for idx in range(0,channels):
        mask = seg == idx
        nparray[idx,:,:] = mask

        if idx == 7:
            idx_ignore = 100
            mask = seg == idx_ignore
            nparray[idx,:,:] = mask

    return nparray

# %% [markdown]
# # Part 1:
# <br> In the below cell that defines ComponentCustomDataset add 1 or more additional transformations to self.trans
# <br> Refer to the following documentation to learn how to add a transformation to self.trans https://pytorch.org/vision/main/generated/torchvision.transforms.Compose.html
# <br> Look at the following pytorch documentation for transforms: https://pytorch.org/vision/stable/transforms.html#transforms-on-pil-image-and-torch-tensor
# <br> Review the following documentation to learn more about Dataset in Pytorch https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset, this class is used to feed images into your neural network

# %%
class ComponentCustomDataset(Dataset):
    def __init__(self, train_df, images_path, labels_path):
        super(ComponentCustomDataset, self).__init__()
        self.csv_path = train_csv_path
        self.image_path = images_path
        self.labels_path = labels_path
        self.train_df = train_df
        #############################################################################
        ## TODO: add 1 or more additional transformations to self.trans             #
        # Refer to sel.rand_trans as an example                                     #
        #############################################################################
        self.trans = transforms.Compose([transforms.ToTensor()])

        ##############################################################################

        self.rand_trans = transforms.Compose([
            # transforms.RandomHorizontalFlip(),
            # transforms.RandomVerticalFlip(),
            # transforms.ColorJitter(brightness=0.2, hue=0.2),
            ])

    def __getitem__(self, index):
        # x is the input
        # y is the label
        seed = np.random.randint(2147483647)
        random.seed(seed)
        torch.manual_seed(seed)

        random_img_name = self.train_df.iloc[index].values[0]

        x = Image.open(os.path.join(self.image_path, random_img_name))
        x = self.trans(x)
        x = self.rand_trans(x)

        random.seed(seed)
        torch.manual_seed(seed)
        y = Image.open(os.path.join(self.labels_path, random_img_name))
        y = self.rand_trans(torch.tensor(np.asarray(y)))
        y = label_to_nparray(np.asarray(y))
        y = torch.tensor(y)

        return x, y

    def __len__(self):
        return self.train_df.shape[0]

# %% [markdown]
# The below cell creates a object of type ComponentCustomDataset that can be used to get sample images and lables by creating an new object of type DataLoader called train_dataloader
# <br> documentation about dataloaders can be found here: https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader

# %%
train_dataset = ComponentCustomDataset(train_df,image_path,label_path)
train_dataloader = DataLoader(train_dataset,batch_size=3,shuffle=True)
train_iter = iter(train_dataloader)
x,y = next(train_iter)

# %% [markdown]
# A sample from the dataloader is taken here, x is a batch of images that would be fed into your neural network during training, y is the corresponding labels
# <br> The shape of x and y are printed below
# <br> Note the dimensions are as follows (batch size, channels, rows, columns)

# %%
print(x.shape)
print(y.shape)
# Out:
# torch.Size([3, 3, 270, 480])
# torch.Size([3, 8, 270, 480])

# %% [markdown]
# The following two cells take a single image from the batch of images from the dataloader
# <br> The first cell is of the input image and second is the one hot encoded labels, note the 8 images for the one hot encoded label
# <br> The transformations you have applied should be visible, the cell can be ran multiple times to see additional images

# %%
x,y = next(train_iter)
sample_x = x[0].numpy()
sample_x = np.moveaxis(sample_x,0,-1)
plt.imshow(sample_x)

# %%
sample_y=y[0].numpy()
figure, axis = plt.subplots(1,8,figsize=(20,20))
for i in range(8):
  axis[i].imshow(sample_y[i,:,:])

# %% [markdown]
# # Part 2:
# Edit the below cell to create a CNN for image segmentation. In this assignment, you will create a UNet architecture with resnet connections. The following cell provides starter code, but you must define the forward functions. In particular, your architecture is required employ the following:
#
# * Skip connections similair to ResNet
# * Cross Connections from the start of your model to the end like Unet
# * Batch normalization layers
# * Convolution layers
# * Max pooling layers
#
# **The ResNet Bottleneck**
#
# First, we will define what is termed a "Bottleneck". Bottlenecks can also be understood as a design pattern, consisting of three convolution layers, introduced by the ResNet paper (see Figure 5 in the paper) https://arxiv.org/abs/1512.03385. We've provided you with some sample layers to use. You need to complete the init function and write the forward function.
# <br>You may make a model completly from scratch without using any of the provided sample layers provided in Bottleneck, but your model must employ all of the mentioned layers and connections.

# %%
# The following class creates one block of the resnet bottleneck block shown in Figure 5 of the ResNet paper
class Bottleneck(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(Bottleneck, self).__init__()

        # self.expansion can be used to scale the last number of channels
        # Note in Figure 5 of the ResNet paper the first 2 conv layers had 64 channels
        # This is followed by 64*4=254 channels
        self.expansion = 4

        # self.ii_downsample is a pair of layers to reduce the number of channels in the identity
        self.ii_downsample = None
        # The convolved input x and identity must be the same dimensions create the skip connection
        # self.ii_downsample is used to reduce the number of channels of the identity
        if in_channels != out_channels:
            self.ii_downsample = nn.Sequential(
                nn.Conv2d(in_channels, out_channels*self.expansion,
                          kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels*self.expansion))

        # first convolution and batch norm layer
        self.conv1 = nn.Conv2d(in_channels, out_channels,
                               kernel_size=1, stride=1, padding=0)
        self.batch_norm1 = nn.BatchNorm2d(out_channels)

        #############################################################################
        ## TODO: Define the rest of your your bottleneck based on Figure 5 from the #
        ## ResNet paper. You need two more pairs of conv and batchnorm layers       #
        #############################################################################
        self.conv2 = nn.Conv2d(out_channels, out_channels,
                               kernel_size=3, stride=stride, padding=1)
        self.batch_norm2 = nn.BatchNorm2d(out_channels)

        self.conv3 = nn.Conv2d(
            out_channels, out_channels*self.expansion, kernel_size=1, stride=1, padding=0)
        self.batch_norm3 = nn.BatchNorm2d(out_channels*self.expansion)

        self.i_downsample = self.ii_downsample
        self.stride = stride
        self.relu = nn.ReLU()

    def forward(self, x):
        identity = x.clone()
        #############################################################################
        ## TODO: Edit the forward function to develop the model for your bottleneck #
        #############################################################################
        if self.i_downsample:
            identity = self.i_downsample(identity)

        layers = nn.Sequential(
            self.conv1,
            self.batch_norm1,
            self.relu,
            self.conv2,
            self.batch_norm2,
            self.relu,
            self.conv3,
            self.batch_norm3
        )

        x = torch.add(identity, layers(x))
        x = self.relu(x)
        return x

# %% [markdown]
# **UNetResNet**
#
# Now, we will define our custom UNetResNet network. We will use the Bottleneck layer we just defined to create the encoder. We will use transposed convolutions (nn.ConvTranspose2d) for the decoder. Additionally, we will build skip connections from the encoder to the decoder (represented by the gray arrow in Fig 1. in the UNet paper https://arxiv.org/pdf/1505.04597.pdf. Feel free to change the size of the layers provided in the encoder and decoder. For the forward function, you may use the $nnF.interpolate$ function to get your encoder and decoder feature maps to be the same size so you can concatenate them.
# <br>You may make a model completly from scratch without using any of the provided sample layers provided in UNetResNet, but your model must employ all of the mentioned layers and connections.

# %%
class UNetResnet(nn.Module):
    def __init__(self, num_classes, in_channels=3):
        super(UNetResnet, self).__init__()

        self.initial_layer = nn.Conv2d(
            in_channels, 64, kernel_size=7, stride=2, padding=3, bias=False)

        # encoder
        self.layer1 = Bottleneck(64, 2, stride=1)
        self.layer2 = Bottleneck(2*4, 2*8, stride=2)
        self.layer3 = Bottleneck(2*8*4, 2*8*4*2, stride=2)
        self.layer4 = Bottleneck(512, 2048, stride=2)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # decoder
        self.conv1 = nn.Conv2d(8192, 2176, kernel_size=3, stride=1, padding=1)
        self.upconv1 = nn.ConvTranspose2d(2176, 1152, 4, 2, 1, bias=False)

        self.conv2 = nn.Conv2d(1664, 128, kernel_size=3, stride=1, padding=1)
        self.upconv2 = nn.ConvTranspose2d(128, 96, 4, 2, 1, bias=False)

        self.conv3 = nn.Conv2d(160, 96, kernel_size=3, stride=1, padding=1)
        self.upconv3 = nn.ConvTranspose2d(96, 64, 4, 2, 1, bias=False)

        self.conv4 = nn.Conv2d(72, 64, kernel_size=3, stride=1, padding=1)
        self.upconv4 = nn.ConvTranspose2d(64, 48, 4, 2, 1, bias=False)

        self.conv5 = nn.Conv2d(48, 48, kernel_size=3, stride=1, padding=1)
        self.upconv5 = nn.ConvTranspose2d(48, 32, 4, 2, 1, bias=False)

        self.conv6 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        self.conv7 = nn.Conv2d(32, num_classes, kernel_size=1, bias=False)

    def forward(self, x):
        #############################################################################
        # TODO: Edit the forward function to develop the model for your UNetResNet  #
        #############################################################################

        x = self.initial_layer(x)
        encode1 = self.layer1(x)
        encode2 = self.layer2(encode1)
        encode3 = self.layer3(encode2)
        encode4 = self.layer4(encode3)

        encode4 = self.conv1(encode4)
        upConv1 = self.upconv1(encode4)

        size1 = (encode3.shape[2], encode3.shape[3])
        decode1 = torch.cat([nnF.interpolate(upConv1, size=size1), encode3], 1)

        decode1 = self.conv2(decode1)
        upConv2 = self.upconv2(decode1)
        size2 = (encode2.shape[2], encode2.shape[3])
        decode2 = torch.cat([nnF.interpolate(upConv2, size=size2), encode2], 1)

        decode2 = self.conv3(decode2)
        upConv3 = self.upconv3(decode2)
        size3 = (encode1.shape[2], encode1.shape[3])
        decode3 = torch.cat([nnF.interpolate(upConv3, size=size3), encode1], 1)

        decode3 = self.conv4(decode3)
        upConv4 = self.upconv4(decode3)

        decode4 = self.conv5(upConv4)
        upConv5 = self.upconv5(decode4)

        decode6 = self.conv6(upConv5)
        decode7 = self.conv7(decode6)
        x = self.pool(decode7)

        return x

# %% [markdown]
# The following cell creates the model you have defined and places it into the GPU if it is available
# <br>Note a GPU is needed for this assignment to train in a reasonable amount of time

# %%
model = UNetResnet(num_classes = 8)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
test_out = model(x.to(device))

# %% [markdown]
# # Part 3:
# <br>Create the cross entropy loss function for image segmentation. The input into this function will be the predicted labels, which will not be one hot encoded, and the raw response from your network. Calculate the Cross entropy using the given inputs.

# %%
#############################################################################
# TODO: Implement cross entropy loss function for image segmentation in the #
# CEL function below                                                        #
#############################################################################
def CEL(pred, ground):
  summed_CEL = nnF.cross_entropy(pred, ground)
  return summed_CEL

# %% [markdown]
# The following function uses the loss function you have written to train your model for one epoch

# %%
def train_loop(dataloader, model, optimizer):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    size = len(dataloader.dataset)
    avg_loss = 0
    iteration = 0
    img_count = 0
    for batch, (x, y) in enumerate(dataloader):
    # Compute prediction and loss

      out = model(x.to(device))

      loss = CEL(out,y.to(device).argmax(dim=1))

      # Backpropagation
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      img_count += x.shape[0]
      if iteration % 5 == 0:
          loss, current = loss.item(),img_count
          print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
      avg_loss += loss
      iteration += 1
    return avg_loss/iteration

# %% [markdown]
# # Part 4:
# <br>Edit the following function where indicated to calculate the Intersection Over Union (IOU) given an array of 1's and 0's for the label and predicted values
# <br>The array's will be of shape 270x480

# %%
@torch.no_grad()
def manual_iou(dataloader, model):
  total_miou = 0
  iou_idx = 0
  for batch, (x,y) in enumerate(dataloader):

    #prediction from model
    preds=model(x.to(device))

    #convert labels and prediction to array of labels
    pred_labels = preds.argmax(dim=1)
    true_labels = y.argmax(dim=1)
    #calculates IOU for each label in a class that is present
    for image in range(y.shape[0]):
      image_label = (true_labels[image]).cpu().numpy()
      image_prediction = (pred_labels[image]).cpu().numpy()

      for i in range(8):
        outputs = image_prediction == i
        labels = image_label == i

#############################################################################
# TODO: Calculate intersection and union                                    #
# Set the intersection variable and the union variable only                 #
# Use the outputs and labels variables defined in lines 21 and 22           #
#############################################################################
        intersection = np.logical_and(outputs, labels)
        union = np.logical_or(outputs, labels)
#############################################################################

        #only calculate if labels are present
        if np.sum(union) > 0:
          if np.sum(labels) > 0:
            total_miou += (np.sum(intersection) / np.sum(union))
            #count number of ious calculated
            iou_idx += 1


  return total_miou/iou_idx

# %% [markdown]
# # Part 5:
# <br>The following cell will train your model. Edit the following cell to adjust the hyperparameters of your trained model. Depending on your model, GPU, and hyperparameters expect 3 hours of training time. Expect a difference in your validation mean IOU score and the IOU score on kaggle. These scores may differ unless it is above 0.8 and you correctly implement the IOU function

# %%
from torch.optim.lr_scheduler import ExponentialLR

#############################################################################
# TODO: Tune the hyperparameters used to train your model                   #
#############################################################################
#############################################################################
#Only edit the following hyperparameter:
epochs=10
batch_size=3
learning_rate=0.003
##############################################################################

best_val=1
epoch_list=[]
train_loss_list=[]
val_loss_list=[]
best_epoch=0
best_iou=0
best_iou_epoch=0
iou_list=[]

best_model_path="random"

#optimizer
optimizer = torch.optim.Adam(params=model.parameters(),lr=learning_rate)
lr_scheduler = ExponentialLR(optimizer, gamma=0.8) # 0.99? 0.9? 0.8?

train_df=pd.read_csv(train_csv_path,header=None,index_col=None,delimiter=',')
val_df=pd.read_csv(val_csv_path,header=None,index_col=None,delimiter=',')
test_df=pd.read_csv(test_csv_path,header=None,index_col=None,delimiter=',')

train_comp_dataset = ComponentCustomDataset(train_df,image_path,label_path)
train_comp_dataloader = DataLoader(train_comp_dataset,batch_size=batch_size,shuffle=True)

val_comp_dataset = ComponentCustomDataset(val_df,image_path,label_path)
val_comp_dataloader = DataLoader(val_comp_dataset,batch_size=batch_size,shuffle=True)


for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    epoch_list.append(t)

    train_loss=train_loop(train_comp_dataloader,model, optimizer)
    train_loss_list.append(train_loss)
    lr_scheduler.step()

    temp_iou=manual_iou(val_comp_dataloader,model)
    print(f"Validation mIOU is: {temp_iou}")

    iou_list.append(temp_iou)
    if temp_iou>best_iou:
        print(f'new best iou: {temp_iou}')
        best_iou=temp_iou

        best_model_path=os.path.join(main_path,"best_validation_model.pth")
        torch.save(model.state_dict(), best_model_path)


print("Done!")
print("loading best saved model")
model.load_state_dict(torch.load(best_model_path))
# Out:
# Epoch 1
# -------------------------------
# loss: 2.058504  [    3/ 2130]
# loss: 1.881147  [   18/ 2130]
# loss: 2.323706  [   33/ 2130]
# loss: 1.721081  [   48/ 2130]
# loss: 1.265344  [   63/ 2130]
# loss: 1.247086  [   78/ 2130]
# loss: 1.005362  [   93/ 2130]
# loss: 1.688159  [  108/ 2130]
# loss: 1.389741  [  123/ 2130]
# loss: 1.475139  [  138/ 2130]
# loss: 1.224149  [  153/ 2130]
# loss: 1.494513  [  168/ 2130]
# loss: 1.624035  [  183/ 2130]
# loss: 1.857007  [  198/ 2130]
# loss: 1.288219  [  213/ 2130]
# loss: 1.390375  [  228/ 2130]
# loss: 1.243872  [  243/ 2130]
# loss: 1.453161  [  258/ 2130]
# loss: 1.279788  [  273/ 2130]
# loss: 0.979727  [  288/ 2130]
# loss: 1.594998  [  303/ 2130]
# loss: 1.304093  [  318/ 2130]
# loss: 1.327505  [  333/ 2130]
# loss: 1.006581  [  348/ 2130]
# loss: 1.234609  [  363/ 2130]
# loss: 1.426542  [  378/ 2130]
# loss: 1.706086  [  393/ 2130]
# loss: 1.075649  [  408/ 2130]
# loss: 1.366305  [  423/ 2130]
# loss: 2.041092  [  438/ 2130]
# loss: 1.331084  [  453/ 2130]
# loss: 1.126238  [  468/ 2130]
# loss: 1.701134  [  483/ 2130]
# loss: 1.611739  [  498/ 2130]
# loss: 1.622510  [  513/ 2130]
# loss: 1.283877  [  528/ 2130]
# loss: 0.973249  [  543/ 2130]
# loss: 1.243207  [  558/ 2130]
# loss: 1.035509  [  573/ 2130]
# loss: 1.102511  [  588/ 2130]
# loss: 1.444694  [  603/ 2130]
# loss: 1.820462  [  618/ 2130]
# loss: 1.279431  [  633/ 2130]
# loss: 1.124315  [  648/ 2130]
# loss: 1.333020  [  663/ 2130]
# loss: 1.329962  [  678/ 2130]
# loss: 1.253969  [  693/ 2130]
# loss: 1.195793  [  708/ 2130]
# loss: 1.398847  [  723/ 2130]
# loss: 1.667055  [  738/ 2130]
# loss: 1.085040  [  753/ 2130]
# loss: 1.236368  [  768/ 2130]
# loss: 1.287784  [  783/ 2130]
# loss: 0.891082  [  798/ 2130]
# loss: 1.429191  [  813/ 2130]
# loss: 1.300673  [  828/ 2130]
# loss: 1.170589  [  843/ 2130]
# loss: 1.133880  [  858/ 2130]
# loss: 1.181629  [  873/ 2130]
# loss: 1.673173  [  888/ 2130]
# loss: 1.203615  [  903/ 2130]
# loss: 1.064594  [  918/ 2130]
# loss: 1.359925  [  933/ 2130]
# loss: 1.553790  [  948/ 2130]
# loss: 1.316139  [  963/ 2130]
# loss: 1.560898  [  978/ 2130]
# loss: 2.230170  [  993/ 2130]
# loss: 1.447148  [ 1008/ 2130]
# loss: 1.319712  [ 1023/ 2130]
# loss: 1.093074  [ 1038/ 2130]
# loss: 1.164901  [ 1053/ 2130]
# loss: 0.925202  [ 1068/ 2130]
# loss: 1.409284  [ 1083/ 2130]
# loss: 1.336004  [ 1098/ 2130]
# loss: 1.414750  [ 1113/ 2130]
# loss: 1.245913  [ 1128/ 2130]
# loss: 0.974930  [ 1143/ 2130]
# loss: 1.103871  [ 1158/ 2130]
# loss: 2.934151  [ 1173/ 2130]
# loss: 1.334373  [ 1188/ 2130]
# loss: 1.150347  [ 1203/ 2130]
# loss: 2.441213  [ 1218/ 2130]
# loss: 1.417551  [ 1233/ 2130]
# loss: 1.551402  [ 1248/ 2130]
# loss: 1.031460  [ 1263/ 2130]
# loss: 1.174642  [ 1278/ 2130]
# loss: 1.225729  [ 1293/ 2130]
# loss: 1.115946  [ 1308/ 2130]
# loss: 1.479612  [ 1323/ 2130]
# loss: 1.294900  [ 1338/ 2130]
# loss: 1.058357  [ 1353/ 2130]
# loss: 1.168559  [ 1368/ 2130]
# loss: 0.946532  [ 1383/ 2130]
# loss: 1.433996  [ 1398/ 2130]
# loss: 1.255922  [ 1413/ 2130]
# loss: 1.244894  [ 1428/ 2130]
# loss: 0.836272  [ 1443/ 2130]
# loss: 1.225249  [ 1458/ 2130]
# loss: 1.366652  [ 1473/ 2130]
# loss: 1.240026  [ 1488/ 2130]
# loss: 1.078499  [ 1503/ 2130]
# loss: 1.218269  [ 1518/ 2130]
# loss: 1.036544  [ 1533/ 2130]
# loss: 0.990585  [ 1548/ 2130]
# loss: 1.255152  [ 1563/ 2130]
# loss: 1.111172  [ 1578/ 2130]
# loss: 1.056144  [ 1593/ 2130]
# loss: 0.837842  [ 1608/ 2130]
# loss: 1.469262  [ 1623/ 2130]
# loss: 1.195136  [ 1638/ 2130]
# loss: 0.970659  [ 1653/ 2130]
# loss: 1.213607  [ 1668/ 2130]
# loss: 1.260244  [ 1683/ 2130]
# loss: 1.196039  [ 1698/ 2130]
# loss: 1.031141  [ 1713/ 2130]
# loss: 1.095491  [ 1728/ 2130]
# loss: 1.039447  [ 1743/ 2130]
# loss: 1.094755  [ 1758/ 2130]
# loss: 0.963170  [ 1773/ 2130]
# loss: 2.015351  [ 1788/ 2130]
# loss: 1.221445  [ 1803/ 2130]
# loss: 1.171631  [ 1818/ 2130]
# loss: 2.138410  [ 1833/ 2130]
# loss: 1.488822  [ 1848/ 2130]
# loss: 1.249286  [ 1863/ 2130]
# loss: 0.969594  [ 1878/ 2130]
# loss: 0.878565  [ 1893/ 2130]
# loss: 1.310340  [ 1908/ 2130]
# loss: 1.288870  [ 1923/ 2130]
# loss: 0.887813  [ 1938/ 2130]
# loss: 0.972288  [ 1953/ 2130]
# loss: 1.233352  [ 1968/ 2130]
# loss: 1.639983  [ 1983/ 2130]
# loss: 1.125379  [ 1998/ 2130]
# loss: 1.484634  [ 2013/ 2130]
# loss: 1.330720  [ 2028/ 2130]
# loss: 1.066929  [ 2043/ 2130]
# loss: 1.748015  [ 2058/ 2130]
# loss: 1.131117  [ 2073/ 2130]
# loss: 1.070052  [ 2088/ 2130]
# loss: 1.422261  [ 2103/ 2130]
# loss: 1.668931  [ 2118/ 2130]
# Validation mIOU is: 0.13638823767598124
# new best iou: 0.13638823767598124
# Epoch 2
# -------------------------------
# loss: 1.068791  [    3/ 2130]
# loss: 1.042515  [   18/ 2130]
# loss: 1.010841  [   33/ 2130]
# loss: 0.881925  [   48/ 2130]
# loss: 1.208144  [   63/ 2130]
# loss: 1.404038  [   78/ 2130]
# loss: 2.065569  [   93/ 2130]
# loss: 1.233573  [  108/ 2130]
# loss: 1.004641  [  123/ 2130]
# loss: 0.986573  [  138/ 2130]
# loss: 1.162302  [  153/ 2130]
# loss: 2.518814  [  168/ 2130]
# loss: 1.085258  [  183/ 2130]
# loss: 1.216958  [  198/ 2130]
# loss: 0.976532  [  213/ 2130]
# loss: 1.373148  [  228/ 2130]
# loss: 0.888807  [  243/ 2130]
# loss: 0.817664  [  258/ 2130]
# loss: 0.931808  [  273/ 2130]
# loss: 1.222693  [  288/ 2130]
# loss: 1.186227  [  303/ 2130]
# loss: 1.286098  [  318/ 2130]
# loss: 0.950920  [  333/ 2130]
# loss: 1.851299  [  348/ 2130]
# loss: 1.281505  [  363/ 2130]
# loss: 1.265903  [  378/ 2130]
# loss: 1.598394  [  393/ 2130]
# loss: 1.412299  [  408/ 2130]
# loss: 0.922232  [  423/ 2130]
# loss: 0.842003  [  438/ 2130]
# loss: 1.134702  [  453/ 2130]
# loss: 1.013077  [  468/ 2130]
# loss: 1.449973  [  483/ 2130]
# loss: 1.341991  [  498/ 2130]
# loss: 1.450578  [  513/ 2130]
# loss: 1.182064  [  528/ 2130]
# loss: 0.906586  [  543/ 2130]
# loss: 1.140068  [  558/ 2130]
# loss: 1.138541  [  573/ 2130]
# loss: 1.278458  [  588/ 2130]
# loss: 1.329732  [  603/ 2130]
# loss: 0.933427  [  618/ 2130]
# loss: 1.160552  [  633/ 2130]
# loss: 1.157097  [  648/ 2130]
# loss: 1.009974  [  663/ 2130]
# loss: 0.885815  [  678/ 2130]
# loss: 2.539496  [  693/ 2130]
# loss: 1.049681  [  708/ 2130]
# loss: 1.107502  [  723/ 2130]
# loss: 1.440887  [  738/ 2130]
# loss: 1.042499  [  753/ 2130]
# loss: 1.208259  [  768/ 2130]
# loss: 0.994780  [  783/ 2130]
# loss: 1.051701  [  798/ 2130]
# loss: 1.004067  [  813/ 2130]
# loss: 0.980455  [  828/ 2130]
# loss: 1.005521  [  843/ 2130]
# loss: 0.770844  [  858/ 2130]
# loss: 1.220354  [  873/ 2130]
# loss: 1.089350  [  888/ 2130]
# loss: 1.052403  [  903/ 2130]
# loss: 1.182762  [  918/ 2130]
# loss: 0.998032  [  933/ 2130]
# loss: 1.011516  [  948/ 2130]
# loss: 0.905171  [  963/ 2130]
# loss: 1.166368  [  978/ 2130]
# loss: 1.235403  [  993/ 2130]
# loss: 1.417443  [ 1008/ 2130]
# loss: 0.812538  [ 1023/ 2130]
# loss: 1.365303  [ 1038/ 2130]
# loss: 1.052625  [ 1053/ 2130]
# loss: 1.185628  [ 1068/ 2130]
# loss: 0.857093  [ 1083/ 2130]
# loss: 1.634014  [ 1098/ 2130]
# loss: 0.800470  [ 1113/ 2130]
# loss: 1.742227  [ 1128/ 2130]
# loss: 0.905012  [ 1143/ 2130]
# loss: 1.082365  [ 1158/ 2130]
# loss: 1.434788  [ 1173/ 2130]
# loss: 1.440416  [ 1188/ 2130]
# loss: 0.918417  [ 1203/ 2130]
# loss: 1.415012  [ 1218/ 2130]
# loss: 1.062770  [ 1233/ 2130]
# loss: 1.021870  [ 1248/ 2130]
# loss: 0.957704  [ 1263/ 2130]
# loss: 1.427212  [ 1278/ 2130]
# loss: 0.865143  [ 1293/ 2130]
# loss: 0.779676  [ 1308/ 2130]
# loss: 1.521720  [ 1323/ 2130]
# loss: 1.045008  [ 1338/ 2130]
# loss: 1.377655  [ 1353/ 2130]
# loss: 1.131848  [ 1368/ 2130]
# loss: 0.962884  [ 1383/ 2130]
# loss: 1.229714  [ 1398/ 2130]
# loss: 1.039208  [ 1413/ 2130]
# loss: 1.354417  [ 1428/ 2130]
# loss: 1.366935  [ 1443/ 2130]
# loss: 1.099540  [ 1458/ 2130]
# loss: 1.347822  [ 1473/ 2130]
# loss: 1.120317  [ 1488/ 2130]
# loss: 0.999867  [ 1503/ 2130]
# loss: 1.207368  [ 1518/ 2130]
# loss: 1.423335  [ 1533/ 2130]
# loss: 0.993313  [ 1548/ 2130]
# loss: 1.254243  [ 1563/ 2130]
# loss: 1.176885  [ 1578/ 2130]
# loss: 1.018758  [ 1593/ 2130]
# loss: 1.175525  [ 1608/ 2130]
# loss: 0.894899  [ 1623/ 2130]
# loss: 1.085949  [ 1638/ 2130]
# loss: 1.219782  [ 1653/ 2130]
# loss: 1.084493  [ 1668/ 2130]
# loss: 0.942018  [ 1683/ 2130]
# loss: 1.000397  [ 1698/ 2130]
# loss: 0.997698  [ 1713/ 2130]
# loss: 0.904329  [ 1728/ 2130]
# loss: 0.894669  [ 1743/ 2130]
# loss: 1.336615  [ 1758/ 2130]
# loss: 1.111330  [ 1773/ 2130]
# loss: 0.802262  [ 1788/ 2130]
# loss: 0.981974  [ 1803/ 2130]
# loss: 0.906569  [ 1818/ 2130]
# loss: 0.775177  [ 1833/ 2130]
# loss: 0.774915  [ 1848/ 2130]
# loss: 0.868656  [ 1863/ 2130]
# loss: 1.365305  [ 1878/ 2130]
# loss: 1.268757  [ 1893/ 2130]
# loss: 1.150724  [ 1908/ 2130]
# loss: 1.106991  [ 1923/ 2130]
# loss: 1.135960  [ 1938/ 2130]
# loss: 1.534529  [ 1953/ 2130]
# loss: 1.442949  [ 1968/ 2130]
# loss: 1.054464  [ 1983/ 2130]
# loss: 1.153402  [ 1998/ 2130]
# loss: 0.888737  [ 2013/ 2130]
# loss: 1.055235  [ 2028/ 2130]
# loss: 1.247341  [ 2043/ 2130]
# loss: 1.037357  [ 2058/ 2130]
# loss: 1.153200  [ 2073/ 2130]
# loss: 1.093908  [ 2088/ 2130]
# loss: 1.125051  [ 2103/ 2130]
# loss: 1.089253  [ 2118/ 2130]
# Validation mIOU is: 0.17826352932587236
# new best iou: 0.17826352932587236
# Epoch 3
# -------------------------------
# loss: 0.942443  [    3/ 2130]
# loss: 1.774634  [   18/ 2130]
# loss: 0.948422  [   33/ 2130]
# loss: 1.053760  [   48/ 2130]
# loss: 1.151281  [   63/ 2130]
# loss: 1.109157  [   78/ 2130]
# loss: 1.078926  [   93/ 2130]
# loss: 0.904236  [  108/ 2130]
# loss: 1.793710  [  123/ 2130]
# loss: 1.157370  [  138/ 2130]
# loss: 1.235726  [  153/ 2130]
# loss: 0.924655  [  168/ 2130]
# loss: 0.942623  [  183/ 2130]
# loss: 1.220497  [  198/ 2130]
# loss: 0.829624  [  213/ 2130]
# loss: 0.979238  [  228/ 2130]
# loss: 0.776036  [  243/ 2130]
# loss: 1.620245  [  258/ 2130]
# loss: 0.949102  [  273/ 2130]
# loss: 0.776789  [  288/ 2130]
# loss: 0.883600  [  303/ 2130]
# loss: 0.911510  [  318/ 2130]
# loss: 1.091094  [  333/ 2130]
# loss: 0.871516  [  348/ 2130]
# loss: 0.956673  [  363/ 2130]
# loss: 0.933263  [  378/ 2130]
# loss: 0.870617  [  393/ 2130]
# loss: 0.993742  [  408/ 2130]
# loss: 1.036246  [  423/ 2130]
# loss: 0.657194  [  438/ 2130]
# loss: 0.857614  [  453/ 2130]
# loss: 1.003864  [  468/ 2130]
# loss: 1.852444  [  483/ 2130]
# loss: 1.165537  [  498/ 2130]
# loss: 1.113006  [  513/ 2130]
# loss: 1.099345  [  528/ 2130]
# loss: 1.048034  [  543/ 2130]
# loss: 0.875363  [  558/ 2130]
# loss: 1.849621  [  573/ 2130]
# loss: 1.693001  [  588/ 2130]
# loss: 0.906745  [  603/ 2130]
# loss: 1.229198  [  618/ 2130]
# loss: 1.086771  [  633/ 2130]
# loss: 0.856498  [  648/ 2130]
# loss: 0.891645  [  663/ 2130]
# loss: 1.864442  [  678/ 2130]
# loss: 1.879663  [  693/ 2130]
# loss: 1.162953  [  708/ 2130]
# loss: 1.079705  [  723/ 2130]
# loss: 0.946894  [  738/ 2130]
# loss: 0.919121  [  753/ 2130]
# loss: 1.110679  [  768/ 2130]
# loss: 0.977915  [  783/ 2130]
# loss: 1.163443  [  798/ 2130]
# loss: 1.696895  [  813/ 2130]
# loss: 1.091828  [  828/ 2130]
# loss: 1.109670  [  843/ 2130]
# loss: 1.147949  [  858/ 2130]
# loss: 1.140889  [  873/ 2130]
# loss: 1.141214  [  888/ 2130]
# loss: 1.397855  [  903/ 2130]
# loss: 1.027784  [  918/ 2130]
# loss: 0.904550  [  933/ 2130]
# loss: 0.562571  [  948/ 2130]
# loss: 0.895954  [  963/ 2130]
# loss: 1.021542  [  978/ 2130]
# loss: 1.073506  [  993/ 2130]
# loss: 0.945028  [ 1008/ 2130]
# loss: 0.823188  [ 1023/ 2130]
# loss: 0.752116  [ 1038/ 2130]
# loss: 0.759142  [ 1053/ 2130]
# loss: 0.817308  [ 1068/ 2130]
# loss: 0.847512  [ 1083/ 2130]
# loss: 0.891990  [ 1098/ 2130]
# loss: 1.277048  [ 1113/ 2130]
# loss: 0.845984  [ 1128/ 2130]
# loss: 0.813893  [ 1143/ 2130]
# loss: 0.899159  [ 1158/ 2130]
# loss: 0.907052  [ 1173/ 2130]
# loss: 1.016537  [ 1188/ 2130]
# loss: 0.781662  [ 1203/ 2130]
# loss: 0.846625  [ 1218/ 2130]
# loss: 1.428749  [ 1233/ 2130]
# loss: 1.105685  [ 1248/ 2130]
# loss: 0.978142  [ 1263/ 2130]
# loss: 0.833542  [ 1278/ 2130]
# loss: 0.730959  [ 1293/ 2130]
# loss: 0.739180  [ 1308/ 2130]
# loss: 0.779124  [ 1323/ 2130]
# loss: 0.702162  [ 1338/ 2130]
# loss: 0.916904  [ 1353/ 2130]
# loss: 0.943527  [ 1368/ 2130]
# loss: 0.782817  [ 1383/ 2130]
# loss: 0.854837  [ 1398/ 2130]
# loss: 1.025818  [ 1413/ 2130]
# loss: 0.726600  [ 1428/ 2130]
# loss: 0.971995  [ 1443/ 2130]
# loss: 0.989652  [ 1458/ 2130]
# loss: 0.786127  [ 1473/ 2130]
# loss: 1.016755  [ 1488/ 2130]
# loss: 0.721850  [ 1503/ 2130]
# loss: 1.026424  [ 1518/ 2130]
# loss: 1.014605  [ 1533/ 2130]
# loss: 1.065911  [ 1548/ 2130]
# loss: 0.602327  [ 1563/ 2130]
# loss: 0.918677  [ 1578/ 2130]
# loss: 0.926668  [ 1593/ 2130]
# loss: 1.199737  [ 1608/ 2130]
# loss: 1.122329  [ 1623/ 2130]
# loss: 0.850286  [ 1638/ 2130]
# loss: 0.917864  [ 1653/ 2130]
# loss: 1.033666  [ 1668/ 2130]
# loss: 1.496423  [ 1683/ 2130]
# loss: 1.123586  [ 1698/ 2130]
# loss: 0.966643  [ 1713/ 2130]
# loss: 1.000885  [ 1728/ 2130]
# loss: 1.881258  [ 1743/ 2130]
# loss: 0.978891  [ 1758/ 2130]
# loss: 1.024635  [ 1773/ 2130]
# loss: 1.460597  [ 1788/ 2130]
# loss: 0.760095  [ 1803/ 2130]
# loss: 1.025431  [ 1818/ 2130]
# loss: 1.084624  [ 1833/ 2130]
# loss: 0.999433  [ 1848/ 2130]
# loss: 0.733973  [ 1863/ 2130]
# loss: 0.928515  [ 1878/ 2130]
# loss: 0.949710  [ 1893/ 2130]
# loss: 1.099680  [ 1908/ 2130]
# loss: 0.838532  [ 1923/ 2130]
# loss: 1.096916  [ 1938/ 2130]
# loss: 0.891694  [ 1953/ 2130]
# loss: 1.035934  [ 1968/ 2130]
# loss: 1.387009  [ 1983/ 2130]
# loss: 0.904340  [ 1998/ 2130]
# loss: 0.953440  [ 2013/ 2130]
# loss: 1.134614  [ 2028/ 2130]
# loss: 1.029322  [ 2043/ 2130]
# loss: 1.025113  [ 2058/ 2130]
# loss: 0.983987  [ 2073/ 2130]
# loss: 1.726688  [ 2088/ 2130]
# loss: 1.191079  [ 2103/ 2130]
# loss: 1.008669  [ 2118/ 2130]
# Validation mIOU is: 0.2560045806271889
# new best iou: 0.2560045806271889
# Epoch 4
# -------------------------------
# loss: 1.134147  [    3/ 2130]
# loss: 0.819169  [   18/ 2130]
# loss: 0.828217  [   33/ 2130]
# loss: 1.718985  [   48/ 2130]
# loss: 0.882723  [   63/ 2130]
# loss: 1.173361  [   78/ 2130]
# loss: 0.691361  [   93/ 2130]
# loss: 0.855364  [  108/ 2130]
# loss: 1.053972  [  123/ 2130]
# loss: 0.776056  [  138/ 2130]
# loss: 0.779720  [  153/ 2130]
# loss: 0.833062  [  168/ 2130]
# loss: 0.836453  [  183/ 2130]
# loss: 0.849159  [  198/ 2130]
# loss: 0.830544  [  213/ 2130]
# loss: 0.857882  [  228/ 2130]
# loss: 0.800372  [  243/ 2130]
# loss: 0.860541  [  258/ 2130]
# loss: 0.803055  [  273/ 2130]
# loss: 0.668083  [  288/ 2130]
# loss: 0.951830  [  303/ 2130]
# loss: 0.679412  [  318/ 2130]
# loss: 0.892610  [  333/ 2130]
# loss: 0.877424  [  348/ 2130]
# loss: 0.918339  [  363/ 2130]
# loss: 0.842446  [  378/ 2130]
# loss: 0.965197  [  393/ 2130]
# loss: 0.727035  [  408/ 2130]
# loss: 1.235078  [  423/ 2130]
# loss: 0.667068  [  438/ 2130]
# loss: 0.720372  [  453/ 2130]
# loss: 1.063756  [  468/ 2130]
# loss: 0.579190  [  483/ 2130]
# loss: 1.274709  [  498/ 2130]
# loss: 0.826348  [  513/ 2130]
# loss: 0.820920  [  528/ 2130]
# loss: 1.245433  [  543/ 2130]
# loss: 0.957673  [  558/ 2130]
# loss: 1.011184  [  573/ 2130]
# loss: 0.835078  [  588/ 2130]
# loss: 1.208951  [  603/ 2130]
# loss: 0.776317  [  618/ 2130]
# loss: 1.321887  [  633/ 2130]
# loss: 0.612800  [  648/ 2130]
# loss: 0.982996  [  663/ 2130]
# loss: 0.565163  [  678/ 2130]
# loss: 1.271535  [  693/ 2130]
# loss: 0.699710  [  708/ 2130]
# loss: 0.753844  [  723/ 2130]
# loss: 0.892121  [  738/ 2130]
# loss: 0.978974  [  753/ 2130]
# loss: 0.634103  [  768/ 2130]
# loss: 0.897426  [  783/ 2130]
# loss: 1.141704  [  798/ 2130]
# loss: 0.770688  [  813/ 2130]
# loss: 0.868853  [  828/ 2130]
# loss: 1.155248  [  843/ 2130]
# loss: 0.975013  [  858/ 2130]
# loss: 0.848659  [  873/ 2130]
# loss: 0.774754  [  888/ 2130]
# loss: 0.957671  [  903/ 2130]
# loss: 1.063523  [  918/ 2130]
# loss: 0.582437  [  933/ 2130]
# loss: 1.961047  [  948/ 2130]
# loss: 0.795104  [  963/ 2130]
# loss: 0.733611  [  978/ 2130]
# loss: 0.697632  [  993/ 2130]
# loss: 0.689163  [ 1008/ 2130]
# loss: 0.916454  [ 1023/ 2130]
# loss: 0.741855  [ 1038/ 2130]
# loss: 0.484091  [ 1053/ 2130]
# loss: 1.097230  [ 1068/ 2130]
# loss: 1.051855  [ 1083/ 2130]
# loss: 0.996078  [ 1098/ 2130]
# loss: 0.792467  [ 1113/ 2130]
# loss: 0.932121  [ 1128/ 2130]
# loss: 0.690450  [ 1143/ 2130]
# loss: 0.811657  [ 1158/ 2130]
# loss: 0.826076  [ 1173/ 2130]
# loss: 1.177156  [ 1188/ 2130]
# loss: 0.835062  [ 1203/ 2130]
# loss: 0.981583  [ 1218/ 2130]
# loss: 0.769065  [ 1233/ 2130]
# loss: 1.065925  [ 1248/ 2130]
# loss: 0.949610  [ 1263/ 2130]
# loss: 1.337177  [ 1278/ 2130]
# loss: 0.893548  [ 1293/ 2130]
# loss: 0.731092  [ 1308/ 2130]
# loss: 0.889881  [ 1323/ 2130]
# loss: 0.688068  [ 1338/ 2130]
# loss: 0.817728  [ 1353/ 2130]
# loss: 0.781075  [ 1368/ 2130]
# loss: 1.193644  [ 1383/ 2130]
# loss: 1.118258  [ 1398/ 2130]
# loss: 0.850740  [ 1413/ 2130]
# loss: 0.926359  [ 1428/ 2130]
# loss: 0.925661  [ 1443/ 2130]
# loss: 0.867143  [ 1458/ 2130]
# loss: 0.753565  [ 1473/ 2130]
# loss: 0.989270  [ 1488/ 2130]
# loss: 0.964375  [ 1503/ 2130]
# loss: 1.086553  [ 1518/ 2130]
# loss: 0.829050  [ 1533/ 2130]
# loss: 1.334458  [ 1548/ 2130]
# loss: 0.747753  [ 1563/ 2130]
# loss: 0.830430  [ 1578/ 2130]
# loss: 0.829767  [ 1593/ 2130]
# loss: 0.651184  [ 1608/ 2130]
# loss: 0.651567  [ 1623/ 2130]
# loss: 0.744776  [ 1638/ 2130]
# loss: 0.571213  [ 1653/ 2130]
# loss: 0.898427  [ 1668/ 2130]
# loss: 0.904837  [ 1683/ 2130]
# loss: 0.974478  [ 1698/ 2130]
# loss: 0.507569  [ 1713/ 2130]
# loss: 0.685761  [ 1728/ 2130]
# loss: 0.853145  [ 1743/ 2130]
# loss: 0.761696  [ 1758/ 2130]
# loss: 0.763992  [ 1773/ 2130]
# loss: 0.574147  [ 1788/ 2130]
# loss: 0.569752  [ 1803/ 2130]
# loss: 1.481808  [ 1818/ 2130]
# loss: 0.876233  [ 1833/ 2130]
# loss: 0.694252  [ 1848/ 2130]
# loss: 0.836295  [ 1863/ 2130]
# loss: 0.708228  [ 1878/ 2130]
# loss: 0.751788  [ 1893/ 2130]
# loss: 0.881241  [ 1908/ 2130]
# loss: 0.761874  [ 1923/ 2130]
# loss: 1.189234  [ 1938/ 2130]
# loss: 1.012518  [ 1953/ 2130]
# loss: 0.849312  [ 1968/ 2130]
# loss: 1.001590  [ 1983/ 2130]
# loss: 1.259216  [ 1998/ 2130]
# loss: 0.767235  [ 2013/ 2130]
# loss: 0.886861  [ 2028/ 2130]
# loss: 0.681656  [ 2043/ 2130]
# loss: 0.504465  [ 2058/ 2130]
# loss: 0.699745  [ 2073/ 2130]
# loss: 0.641907  [ 2088/ 2130]
# loss: 0.900455  [ 2103/ 2130]
# loss: 0.658490  [ 2118/ 2130]
# Validation mIOU is: 0.3442177855688659
# new best iou: 0.3442177855688659
# Epoch 5
# -------------------------------
# loss: 0.971847  [    3/ 2130]
# loss: 0.697103  [   18/ 2130]
# loss: 1.021476  [   33/ 2130]
# loss: 0.630498  [   48/ 2130]
# loss: 1.256429  [   63/ 2130]
# loss: 0.705540  [   78/ 2130]
# loss: 0.812212  [   93/ 2130]
# loss: 0.782830  [  108/ 2130]
# loss: 0.783656  [  123/ 2130]
# loss: 0.630352  [  138/ 2130]
# loss: 0.485171  [  153/ 2130]
# loss: 0.666410  [  168/ 2130]
# loss: 0.771368  [  183/ 2130]
# loss: 0.711032  [  198/ 2130]
# loss: 0.793883  [  213/ 2130]
# loss: 0.981278  [  228/ 2130]
# loss: 0.740234  [  243/ 2130]
# loss: 0.713509  [  258/ 2130]
# loss: 0.662143  [  273/ 2130]
# loss: 0.908188  [  288/ 2130]
# loss: 0.807459  [  303/ 2130]
# loss: 1.135699  [  318/ 2130]
# loss: 0.869688  [  333/ 2130]
# loss: 0.873796  [  348/ 2130]
# loss: 0.530774  [  363/ 2130]
# loss: 0.763956  [  378/ 2130]
# loss: 0.841951  [  393/ 2130]
# loss: 0.736206  [  408/ 2130]
# loss: 0.700092  [  423/ 2130]
# loss: 0.640760  [  438/ 2130]
# loss: 1.002647  [  453/ 2130]
# loss: 0.727345  [  468/ 2130]
# loss: 0.519833  [  483/ 2130]
# loss: 0.775392  [  498/ 2130]
# loss: 0.648495  [  513/ 2130]
# loss: 0.707814  [  528/ 2130]
# loss: 0.521500  [  543/ 2130]
# loss: 0.599975  [  558/ 2130]
# loss: 0.676341  [  573/ 2130]
# loss: 0.540809  [  588/ 2130]
# loss: 0.650660  [  603/ 2130]
# loss: 1.045050  [  618/ 2130]
# loss: 0.661631  [  633/ 2130]
# loss: 0.643195  [  648/ 2130]
# loss: 0.724859  [  663/ 2130]
# loss: 0.929454  [  678/ 2130]
# loss: 0.907046  [  693/ 2130]
# loss: 0.621355  [  708/ 2130]
# loss: 1.102273  [  723/ 2130]
# loss: 0.864014  [  738/ 2130]
# loss: 0.657147  [  753/ 2130]
# loss: 0.534857  [  768/ 2130]
# loss: 0.781656  [  783/ 2130]
# loss: 2.167143  [  798/ 2130]
# loss: 0.709737  [  813/ 2130]
# loss: 0.664787  [  828/ 2130]
# loss: 1.001999  [  843/ 2130]
# loss: 0.919408  [  858/ 2130]
# loss: 0.687500  [  873/ 2130]
# loss: 0.782521  [  888/ 2130]
# loss: 0.650067  [  903/ 2130]
# loss: 0.688139  [  918/ 2130]
# loss: 0.806107  [  933/ 2130]
# loss: 0.884258  [  948/ 2130]
# loss: 0.741314  [  963/ 2130]
# loss: 0.750028  [  978/ 2130]
# loss: 0.663482  [  993/ 2130]
# loss: 0.776622  [ 1008/ 2130]
# loss: 0.668203  [ 1023/ 2130]
# loss: 0.654458  [ 1038/ 2130]
# loss: 0.634694  [ 1053/ 2130]
# loss: 0.634279  [ 1068/ 2130]
# loss: 0.909645  [ 1083/ 2130]
# loss: 0.719499  [ 1098/ 2130]
# loss: 0.605658  [ 1113/ 2130]
# loss: 0.720483  [ 1128/ 2130]
# loss: 1.153348  [ 1143/ 2130]
# loss: 1.327444  [ 1158/ 2130]
# loss: 0.827818  [ 1173/ 2130]
# loss: 0.799424  [ 1188/ 2130]
# loss: 0.985105  [ 1203/ 2130]
# loss: 0.636091  [ 1218/ 2130]
# loss: 0.723595  [ 1233/ 2130]
# loss: 0.756050  [ 1248/ 2130]
# loss: 0.621012  [ 1263/ 2130]
# loss: 0.692005  [ 1278/ 2130]
# loss: 0.809268  [ 1293/ 2130]
# loss: 0.942519  [ 1308/ 2130]
# loss: 0.708887  [ 1323/ 2130]
# loss: 0.691431  [ 1338/ 2130]
# loss: 0.548550  [ 1353/ 2130]
# loss: 0.670458  [ 1368/ 2130]
# loss: 0.587558  [ 1383/ 2130]
# loss: 0.608204  [ 1398/ 2130]
# loss: 0.638828  [ 1413/ 2130]
# loss: 0.734545  [ 1428/ 2130]
# loss: 0.654505  [ 1443/ 2130]
# loss: 0.582677  [ 1458/ 2130]
# loss: 0.755274  [ 1473/ 2130]
# loss: 0.568501  [ 1488/ 2130]
# loss: 0.712676  [ 1503/ 2130]
# loss: 0.908770  [ 1518/ 2130]
# loss: 0.656550  [ 1533/ 2130]
# loss: 0.674035  [ 1548/ 2130]
# loss: 0.607895  [ 1563/ 2130]
# loss: 0.747254  [ 1578/ 2130]
# loss: 0.797026  [ 1593/ 2130]
# loss: 0.643592  [ 1608/ 2130]
# loss: 0.763030  [ 1623/ 2130]
# loss: 0.929054  [ 1638/ 2130]
# loss: 1.035416  [ 1653/ 2130]
# loss: 0.705066  [ 1668/ 2130]
# loss: 0.838192  [ 1683/ 2130]
# loss: 0.736151  [ 1698/ 2130]
# loss: 0.593854  [ 1713/ 2130]
# loss: 0.644503  [ 1728/ 2130]
# loss: 0.548811  [ 1743/ 2130]
# loss: 0.552719  [ 1758/ 2130]
# loss: 0.828238  [ 1773/ 2130]
# loss: 0.731041  [ 1788/ 2130]
# loss: 0.461680  [ 1803/ 2130]
# loss: 0.744941  [ 1818/ 2130]
# loss: 0.548420  [ 1833/ 2130]
# loss: 2.202833  [ 1848/ 2130]
# loss: 0.614006  [ 1863/ 2130]
# loss: 1.102373  [ 1878/ 2130]
# loss: 0.636131  [ 1893/ 2130]
# loss: 0.519472  [ 1908/ 2130]
# loss: 1.122960  [ 1923/ 2130]
# loss: 0.549630  [ 1938/ 2130]
# loss: 1.186855  [ 1953/ 2130]
# loss: 0.628937  [ 1968/ 2130]
# loss: 0.834417  [ 1983/ 2130]
# loss: 0.655156  [ 1998/ 2130]
# loss: 0.442918  [ 2013/ 2130]
# loss: 0.833453  [ 2028/ 2130]
# loss: 0.658106  [ 2043/ 2130]
# loss: 0.631220  [ 2058/ 2130]
# loss: 0.634561  [ 2073/ 2130]
# loss: 0.590118  [ 2088/ 2130]
# loss: 0.648388  [ 2103/ 2130]
# loss: 0.633047  [ 2118/ 2130]
# Validation mIOU is: 0.3527370636400168
# new best iou: 0.3527370636400168
# Epoch 6
# -------------------------------
# loss: 0.658760  [    3/ 2130]
# loss: 0.543186  [   18/ 2130]
# loss: 0.715560  [   33/ 2130]
# loss: 0.552905  [   48/ 2130]
# loss: 0.732616  [   63/ 2130]
# loss: 0.789972  [   78/ 2130]
# loss: 0.485734  [   93/ 2130]
# loss: 0.655372  [  108/ 2130]
# loss: 0.588245  [  123/ 2130]
# loss: 0.505516  [  138/ 2130]
# loss: 0.644745  [  153/ 2130]
# loss: 0.604991  [  168/ 2130]
# loss: 0.680562  [  183/ 2130]
# loss: 1.376909  [  198/ 2130]
# loss: 0.639791  [  213/ 2130]
# loss: 0.646397  [  228/ 2130]
# loss: 0.535866  [  243/ 2130]
# loss: 0.465490  [  258/ 2130]
# loss: 0.380618  [  273/ 2130]
# loss: 0.706260  [  288/ 2130]
# loss: 0.540982  [  303/ 2130]
# loss: 1.499372  [  318/ 2130]
# loss: 0.652770  [  333/ 2130]
# loss: 0.783277  [  348/ 2130]
# loss: 0.822361  [  363/ 2130]
# loss: 0.588706  [  378/ 2130]
# loss: 0.778372  [  393/ 2130]
# loss: 1.059123  [  408/ 2130]
# loss: 0.473148  [  423/ 2130]
# loss: 0.542332  [  438/ 2130]
# loss: 0.605803  [  453/ 2130]
# loss: 0.566117  [  468/ 2130]
# loss: 0.691895  [  483/ 2130]
# loss: 0.787501  [  498/ 2130]
# loss: 0.783305  [  513/ 2130]
# loss: 0.539393  [  528/ 2130]
# loss: 0.722987  [  543/ 2130]
# loss: 0.681839  [  558/ 2130]
# loss: 0.817083  [  573/ 2130]
# loss: 0.772975  [  588/ 2130]
# loss: 0.465931  [  603/ 2130]
# loss: 0.756078  [  618/ 2130]
# loss: 0.648655  [  633/ 2130]
# loss: 0.601822  [  648/ 2130]
# loss: 0.642842  [  663/ 2130]
# loss: 0.606810  [  678/ 2130]
# loss: 0.620422  [  693/ 2130]
# loss: 0.488521  [  708/ 2130]
# loss: 1.301257  [  723/ 2130]
# loss: 0.658460  [  738/ 2130]
# loss: 0.877135  [  753/ 2130]
# loss: 0.748039  [  768/ 2130]
# loss: 0.546459  [  783/ 2130]
# loss: 0.683660  [  798/ 2130]
# loss: 0.314574  [  813/ 2130]
# loss: 0.498315  [  828/ 2130]
# loss: 2.339471  [  843/ 2130]
# loss: 0.711356  [  858/ 2130]
# loss: 0.893296  [  873/ 2130]
# loss: 0.659647  [  888/ 2130]
# loss: 0.604116  [  903/ 2130]
# loss: 0.478540  [  918/ 2130]
# loss: 0.556775  [  933/ 2130]
# loss: 0.642278  [  948/ 2130]
# loss: 0.423191  [  963/ 2130]
# loss: 0.594236  [  978/ 2130]
# loss: 0.778817  [  993/ 2130]
# loss: 0.659201  [ 1008/ 2130]
# loss: 0.516227  [ 1023/ 2130]
# loss: 0.477283  [ 1038/ 2130]
# loss: 0.713322  [ 1053/ 2130]
# loss: 0.710228  [ 1068/ 2130]
# loss: 0.528935  [ 1083/ 2130]
# loss: 0.605899  [ 1098/ 2130]
# loss: 0.919794  [ 1113/ 2130]
# loss: 1.215535  [ 1128/ 2130]
# loss: 0.894856  [ 1143/ 2130]
# loss: 0.754866  [ 1158/ 2130]
# loss: 0.827031  [ 1173/ 2130]
# loss: 0.912782  [ 1188/ 2130]
# loss: 1.128106  [ 1203/ 2130]
# loss: 0.606086  [ 1218/ 2130]
# loss: 0.660242  [ 1233/ 2130]
# loss: 0.662219  [ 1248/ 2130]
# loss: 0.749829  [ 1263/ 2130]
# loss: 0.686149  [ 1278/ 2130]
# loss: 0.783755  [ 1293/ 2130]
# loss: 0.505765  [ 1308/ 2130]
# loss: 0.603263  [ 1323/ 2130]
# loss: 0.712372  [ 1338/ 2130]
# loss: 0.800219  [ 1353/ 2130]
# loss: 0.657212  [ 1368/ 2130]
# loss: 0.687771  [ 1383/ 2130]
# loss: 1.192891  [ 1398/ 2130]
# loss: 0.660481  [ 1413/ 2130]
# loss: 0.652559  [ 1428/ 2130]
# loss: 0.752343  [ 1443/ 2130]
# loss: 0.748730  [ 1458/ 2130]
# loss: 0.841952  [ 1473/ 2130]
# loss: 0.886089  [ 1488/ 2130]
# loss: 1.005842  [ 1503/ 2130]
# loss: 0.537990  [ 1518/ 2130]
# loss: 0.543509  [ 1533/ 2130]
# loss: 0.329946  [ 1548/ 2130]
# loss: 0.420510  [ 1563/ 2130]
# loss: 0.458360  [ 1578/ 2130]
# loss: 0.563517  [ 1593/ 2130]
# loss: 0.608210  [ 1608/ 2130]
# loss: 0.566414  [ 1623/ 2130]
# loss: 0.665576  [ 1638/ 2130]
# loss: 0.845530  [ 1653/ 2130]
# loss: 1.460637  [ 1668/ 2130]
# loss: 0.595440  [ 1683/ 2130]
# loss: 0.597022  [ 1698/ 2130]
# loss: 0.678816  [ 1713/ 2130]
# loss: 0.676548  [ 1728/ 2130]
# loss: 0.766110  [ 1743/ 2130]
# loss: 0.560882  [ 1758/ 2130]
# loss: 0.741198  [ 1773/ 2130]
# loss: 0.770489  [ 1788/ 2130]
# loss: 0.640311  [ 1803/ 2130]
# loss: 0.510121  [ 1818/ 2130]
# loss: 0.549489  [ 1833/ 2130]
# loss: 0.692789  [ 1848/ 2130]
# loss: 0.847800  [ 1863/ 2130]
# loss: 0.662749  [ 1878/ 2130]
# loss: 0.798536  [ 1893/ 2130]
# loss: 0.824014  [ 1908/ 2130]
# loss: 0.847758  [ 1923/ 2130]
# loss: 0.545053  [ 1938/ 2130]
# loss: 0.531596  [ 1953/ 2130]
# loss: 0.592239  [ 1968/ 2130]
# loss: 0.622752  [ 1983/ 2130]
# loss: 0.446813  [ 1998/ 2130]
# loss: 0.497114  [ 2013/ 2130]
# loss: 0.554418  [ 2028/ 2130]
# loss: 0.638583  [ 2043/ 2130]
# loss: 0.695993  [ 2058/ 2130]
# loss: 0.878941  [ 2073/ 2130]
# loss: 0.426739  [ 2088/ 2130]
# loss: 0.901915  [ 2103/ 2130]
# loss: 0.991221  [ 2118/ 2130]
# Validation mIOU is: 0.3736304741111244
# new best iou: 0.3736304741111244
# Epoch 7
# -------------------------------
# loss: 0.583698  [    3/ 2130]
# loss: 0.580807  [   18/ 2130]
# loss: 0.649703  [   33/ 2130]
# loss: 0.591266  [   48/ 2130]
# loss: 0.476794  [   63/ 2130]
# loss: 0.476833  [   78/ 2130]
# loss: 0.826542  [   93/ 2130]
# loss: 0.617828  [  108/ 2130]
# loss: 0.905933  [  123/ 2130]
# loss: 0.731606  [  138/ 2130]
# loss: 0.530943  [  153/ 2130]
# loss: 0.438944  [  168/ 2130]
# loss: 0.544286  [  183/ 2130]
# loss: 0.491043  [  198/ 2130]
# loss: 0.686583  [  213/ 2130]
# loss: 0.754157  [  228/ 2130]
# loss: 0.462198  [  243/ 2130]
# loss: 0.810645  [  258/ 2130]
# loss: 0.766255  [  273/ 2130]
# loss: 0.605589  [  288/ 2130]
# loss: 0.474238  [  303/ 2130]
# loss: 0.553184  [  318/ 2130]
# loss: 0.712881  [  333/ 2130]
# loss: 0.631827  [  348/ 2130]
# loss: 0.641399  [  363/ 2130]
# loss: 0.486794  [  378/ 2130]
# loss: 0.478431  [  393/ 2130]
# loss: 0.475887  [  408/ 2130]
# loss: 0.606361  [  423/ 2130]
# loss: 0.555703  [  438/ 2130]
# loss: 0.555132  [  453/ 2130]
# loss: 0.548937  [  468/ 2130]
# loss: 0.677591  [  483/ 2130]
# loss: 0.555777  [  498/ 2130]
# loss: 0.516899  [  513/ 2130]
# loss: 0.600087  [  528/ 2130]
# loss: 0.722059  [  543/ 2130]
# loss: 0.548800  [  558/ 2130]
# loss: 0.461322  [  573/ 2130]
# loss: 0.573689  [  588/ 2130]
# loss: 0.491561  [  603/ 2130]
# loss: 0.567971  [  618/ 2130]
# loss: 0.703618  [  633/ 2130]
# loss: 0.700343  [  648/ 2130]
# loss: 0.696320  [  663/ 2130]
# loss: 0.572929  [  678/ 2130]
# loss: 0.574312  [  693/ 2130]
# loss: 0.417276  [  708/ 2130]
# loss: 1.059392  [  723/ 2130]
# loss: 0.390838  [  738/ 2130]
# loss: 0.780232  [  753/ 2130]
# loss: 0.630781  [  768/ 2130]
# loss: 0.673716  [  783/ 2130]
# loss: 0.464358  [  798/ 2130]
# loss: 0.538256  [  813/ 2130]
# loss: 0.832054  [  828/ 2130]
# loss: 0.682054  [  843/ 2130]
# loss: 0.677442  [  858/ 2130]
# loss: 0.525242  [  873/ 2130]
# loss: 0.578159  [  888/ 2130]
# loss: 0.740769  [  903/ 2130]
# loss: 0.660752  [  918/ 2130]
# loss: 0.622165  [  933/ 2130]
# loss: 0.755388  [  948/ 2130]
# loss: 0.672165  [  963/ 2130]
# loss: 0.727841  [  978/ 2130]
# loss: 0.698448  [  993/ 2130]
# loss: 0.581286  [ 1008/ 2130]
# loss: 0.706356  [ 1023/ 2130]
# loss: 0.763094  [ 1038/ 2130]
# loss: 0.639060  [ 1053/ 2130]
# loss: 0.600291  [ 1068/ 2130]
# loss: 0.518882  [ 1083/ 2130]
# loss: 0.978694  [ 1098/ 2130]
# loss: 0.523010  [ 1113/ 2130]
# loss: 0.614407  [ 1128/ 2130]
# loss: 0.428676  [ 1143/ 2130]
# loss: 0.726996  [ 1158/ 2130]
# loss: 0.498998  [ 1173/ 2130]
# loss: 0.611421  [ 1188/ 2130]
# loss: 1.046217  [ 1203/ 2130]
# loss: 0.687121  [ 1218/ 2130]
# loss: 0.679513  [ 1233/ 2130]
# loss: 0.423306  [ 1248/ 2130]
# loss: 0.613856  [ 1263/ 2130]
# loss: 0.588339  [ 1278/ 2130]
# loss: 0.612111  [ 1293/ 2130]
# loss: 0.456614  [ 1308/ 2130]
# loss: 0.504060  [ 1323/ 2130]
# loss: 0.840537  [ 1338/ 2130]
# loss: 0.632372  [ 1353/ 2130]
# loss: 0.559739  [ 1368/ 2130]
# loss: 0.776493  [ 1383/ 2130]
# loss: 0.570086  [ 1398/ 2130]
# loss: 0.617717  [ 1413/ 2130]
# loss: 0.444151  [ 1428/ 2130]
# loss: 0.561318  [ 1443/ 2130]
# loss: 0.544371  [ 1458/ 2130]
# loss: 1.024505  [ 1473/ 2130]
# loss: 0.539420  [ 1488/ 2130]
# loss: 0.381320  [ 1503/ 2130]
# loss: 0.928363  [ 1518/ 2130]
# loss: 0.573458  [ 1533/ 2130]
# loss: 0.440737  [ 1548/ 2130]
# loss: 0.665778  [ 1563/ 2130]
# loss: 0.800341  [ 1578/ 2130]
# loss: 0.559859  [ 1593/ 2130]
# loss: 0.726283  [ 1608/ 2130]
# loss: 0.702156  [ 1623/ 2130]
# loss: 0.455747  [ 1638/ 2130]
# loss: 0.538865  [ 1653/ 2130]
# loss: 0.675670  [ 1668/ 2130]
# loss: 0.648091  [ 1683/ 2130]
# loss: 0.527878  [ 1698/ 2130]
# loss: 0.589843  [ 1713/ 2130]
# loss: 0.613083  [ 1728/ 2130]
# loss: 0.581899  [ 1743/ 2130]
# loss: 0.586732  [ 1758/ 2130]
# loss: 0.579516  [ 1773/ 2130]
# loss: 1.138389  [ 1788/ 2130]
# loss: 0.424842  [ 1803/ 2130]
# loss: 0.448152  [ 1818/ 2130]
# loss: 0.586732  [ 1833/ 2130]
# loss: 1.386801  [ 1848/ 2130]
# loss: 0.362892  [ 1863/ 2130]
# loss: 0.849785  [ 1878/ 2130]
# loss: 0.553697  [ 1893/ 2130]
# loss: 0.678417  [ 1908/ 2130]
# loss: 0.517716  [ 1923/ 2130]
# loss: 0.507988  [ 1938/ 2130]
# loss: 0.532687  [ 1953/ 2130]
# loss: 0.392359  [ 1968/ 2130]
# loss: 0.580550  [ 1983/ 2130]
# loss: 0.764815  [ 1998/ 2130]
# loss: 0.548895  [ 2013/ 2130]
# loss: 0.777570  [ 2028/ 2130]
# loss: 0.547680  [ 2043/ 2130]
# loss: 0.391445  [ 2058/ 2130]
# loss: 0.407876  [ 2073/ 2130]
# loss: 0.755722  [ 2088/ 2130]
# loss: 0.411893  [ 2103/ 2130]
# loss: 0.820891  [ 2118/ 2130]
# Validation mIOU is: 0.3994560151752392
# new best iou: 0.3994560151752392
# Epoch 8
# -------------------------------
# loss: 0.679318  [    3/ 2130]
# loss: 0.627189  [   18/ 2130]
# loss: 0.551533  [   33/ 2130]
# loss: 0.628015  [   48/ 2130]
# loss: 0.663949  [   63/ 2130]
# loss: 0.501827  [   78/ 2130]
# loss: 0.369306  [   93/ 2130]
# loss: 0.958040  [  108/ 2130]
# loss: 0.709297  [  123/ 2130]
# loss: 0.508609  [  138/ 2130]
# loss: 0.762719  [  153/ 2130]
# loss: 0.739390  [  168/ 2130]
# loss: 0.471790  [  183/ 2130]
# loss: 0.487779  [  198/ 2130]
# loss: 0.441744  [  213/ 2130]
# loss: 0.615730  [  228/ 2130]
# loss: 0.512441  [  243/ 2130]
# loss: 0.514654  [  258/ 2130]
# loss: 0.662175  [  273/ 2130]
# loss: 0.613172  [  288/ 2130]
# loss: 0.459340  [  303/ 2130]
# loss: 0.411450  [  318/ 2130]
# loss: 0.586733  [  333/ 2130]
# loss: 0.564930  [  348/ 2130]
# loss: 0.603209  [  363/ 2130]
# loss: 0.575379  [  378/ 2130]
# loss: 0.792895  [  393/ 2130]
# loss: 0.329979  [  408/ 2130]
# loss: 0.659854  [  423/ 2130]
# loss: 0.587222  [  438/ 2130]
# loss: 0.667549  [  453/ 2130]
# loss: 0.556230  [  468/ 2130]
# loss: 0.467248  [  483/ 2130]
# loss: 0.729824  [  498/ 2130]
# loss: 0.537939  [  513/ 2130]
# loss: 1.798359  [  528/ 2130]
# loss: 0.403086  [  543/ 2130]
# loss: 0.641355  [  558/ 2130]
# loss: 0.770179  [  573/ 2130]
# loss: 0.506724  [  588/ 2130]
# loss: 0.598435  [  603/ 2130]
# loss: 0.529163  [  618/ 2130]
# loss: 0.616590  [  633/ 2130]
# loss: 0.514265  [  648/ 2130]
# loss: 0.412300  [  663/ 2130]
# loss: 0.467022  [  678/ 2130]
# loss: 0.410440  [  693/ 2130]
# loss: 0.580918  [  708/ 2130]
# loss: 0.422287  [  723/ 2130]
# loss: 0.503652  [  738/ 2130]
# loss: 0.951643  [  753/ 2130]
# loss: 0.480826  [  768/ 2130]
# loss: 0.600391  [  783/ 2130]
# loss: 0.395488  [  798/ 2130]
# loss: 0.419718  [  813/ 2130]
# loss: 0.533298  [  828/ 2130]
# loss: 0.588884  [  843/ 2130]
# loss: 0.628700  [  858/ 2130]
# loss: 0.563747  [  873/ 2130]
# loss: 0.713173  [  888/ 2130]
# loss: 0.619615  [  903/ 2130]
# loss: 0.615464  [  918/ 2130]
# loss: 0.869314  [  933/ 2130]
# loss: 0.886925  [  948/ 2130]
# loss: 0.535139  [  963/ 2130]
# loss: 0.617384  [  978/ 2130]
# loss: 0.444139  [  993/ 2130]
# loss: 0.681734  [ 1008/ 2130]
# loss: 0.405506  [ 1023/ 2130]
# loss: 0.774922  [ 1038/ 2130]
# loss: 0.515238  [ 1053/ 2130]
# loss: 0.451742  [ 1068/ 2130]
# loss: 0.647180  [ 1083/ 2130]
# loss: 0.540902  [ 1098/ 2130]
# loss: 0.584858  [ 1113/ 2130]
# loss: 0.391549  [ 1128/ 2130]
# loss: 0.533826  [ 1143/ 2130]
# loss: 0.536174  [ 1158/ 2130]
# loss: 0.330416  [ 1173/ 2130]
# loss: 0.488827  [ 1188/ 2130]
# loss: 0.534650  [ 1203/ 2130]
# loss: 0.483828  [ 1218/ 2130]
# loss: 0.469115  [ 1233/ 2130]
# loss: 0.640343  [ 1248/ 2130]
# loss: 0.612926  [ 1263/ 2130]
# loss: 0.531303  [ 1278/ 2130]
# loss: 0.577878  [ 1293/ 2130]
# loss: 0.569926  [ 1308/ 2130]
# loss: 0.531714  [ 1323/ 2130]
# loss: 0.510586  [ 1338/ 2130]
# loss: 0.508933  [ 1353/ 2130]
# loss: 0.605089  [ 1368/ 2130]
# loss: 0.412359  [ 1383/ 2130]
# loss: 0.437594  [ 1398/ 2130]
# loss: 0.707996  [ 1413/ 2130]
# loss: 0.506245  [ 1428/ 2130]
# loss: 0.410093  [ 1443/ 2130]
# loss: 0.767756  [ 1458/ 2130]
# loss: 0.514547  [ 1473/ 2130]
# loss: 0.771945  [ 1488/ 2130]
# loss: 0.797600  [ 1503/ 2130]
# loss: 0.496088  [ 1518/ 2130]
# loss: 0.517300  [ 1533/ 2130]
# loss: 0.401010  [ 1548/ 2130]
# loss: 0.309057  [ 1563/ 2130]
# loss: 0.376755  [ 1578/ 2130]
# loss: 0.503747  [ 1593/ 2130]
# loss: 0.744076  [ 1608/ 2130]
# loss: 0.666425  [ 1623/ 2130]
# loss: 0.533752  [ 1638/ 2130]
# loss: 0.397832  [ 1653/ 2130]
# loss: 0.449858  [ 1668/ 2130]
# loss: 0.524535  [ 1683/ 2130]
# loss: 0.417916  [ 1698/ 2130]
# loss: 0.479786  [ 1713/ 2130]
# loss: 0.517968  [ 1728/ 2130]
# loss: 0.605799  [ 1743/ 2130]
# loss: 0.574540  [ 1758/ 2130]
# loss: 0.548018  [ 1773/ 2130]
# loss: 0.660749  [ 1788/ 2130]
# loss: 0.464877  [ 1803/ 2130]
# loss: 0.567957  [ 1818/ 2130]
# loss: 0.614468  [ 1833/ 2130]
# loss: 0.779389  [ 1848/ 2130]
# loss: 0.498306  [ 1863/ 2130]
# loss: 0.583582  [ 1878/ 2130]
# loss: 0.440104  [ 1893/ 2130]
# loss: 0.488863  [ 1908/ 2130]
# loss: 0.477823  [ 1923/ 2130]
# loss: 0.483804  [ 1938/ 2130]
# loss: 0.503681  [ 1953/ 2130]
# loss: 0.668245  [ 1968/ 2130]
# loss: 0.389307  [ 1983/ 2130]
# loss: 0.606704  [ 1998/ 2130]
# loss: 1.598322  [ 2013/ 2130]
# loss: 0.428811  [ 2028/ 2130]
# loss: 0.592398  [ 2043/ 2130]
# loss: 0.603169  [ 2058/ 2130]
# loss: 0.803461  [ 2073/ 2130]
# loss: 0.347816  [ 2088/ 2130]
# loss: 0.673304  [ 2103/ 2130]
# loss: 0.621163  [ 2118/ 2130]
# Validation mIOU is: 0.45328427001125565
# new best iou: 0.45328427001125565
# Epoch 9
# -------------------------------
# loss: 0.551770  [    3/ 2130]
# loss: 0.586342  [   18/ 2130]
# loss: 0.381862  [   33/ 2130]
# loss: 0.542753  [   48/ 2130]
# loss: 0.374390  [   63/ 2130]
# loss: 1.238321  [   78/ 2130]
# loss: 0.612925  [   93/ 2130]
# loss: 0.673850  [  108/ 2130]
# loss: 0.637146  [  123/ 2130]
# loss: 0.469940  [  138/ 2130]
# loss: 0.469249  [  153/ 2130]
# loss: 0.571442  [  168/ 2130]
# loss: 0.362982  [  183/ 2130]
# loss: 0.527215  [  198/ 2130]
# loss: 0.450841  [  213/ 2130]
# loss: 0.383899  [  228/ 2130]
# loss: 0.631262  [  243/ 2130]
# loss: 0.712372  [  258/ 2130]
# loss: 0.471227  [  273/ 2130]
# loss: 0.526489  [  288/ 2130]
# loss: 0.481094  [  303/ 2130]
# loss: 0.447244  [  318/ 2130]
# loss: 0.419045  [  333/ 2130]
# loss: 0.546726  [  348/ 2130]
# loss: 0.562543  [  363/ 2130]
# loss: 0.424319  [  378/ 2130]
# loss: 0.431867  [  393/ 2130]
# loss: 0.578749  [  408/ 2130]
# loss: 0.868680  [  423/ 2130]
# loss: 0.412645  [  438/ 2130]
# loss: 0.438140  [  453/ 2130]
# loss: 0.528440  [  468/ 2130]
# loss: 0.637467  [  483/ 2130]
# loss: 0.806980  [  498/ 2130]
# loss: 0.674455  [  513/ 2130]
# loss: 0.644714  [  528/ 2130]
# loss: 0.391880  [  543/ 2130]
# loss: 0.434834  [  558/ 2130]
# loss: 0.447806  [  573/ 2130]
# loss: 0.521450  [  588/ 2130]
# loss: 0.403707  [  603/ 2130]
# loss: 0.434725  [  618/ 2130]
# loss: 0.599940  [  633/ 2130]
# loss: 0.471659  [  648/ 2130]
# loss: 0.428283  [  663/ 2130]
# loss: 0.409880  [  678/ 2130]
# loss: 0.413803  [  693/ 2130]
# loss: 0.509797  [  708/ 2130]
# loss: 0.549112  [  723/ 2130]
# loss: 0.360545  [  738/ 2130]
# loss: 0.397417  [  753/ 2130]
# loss: 0.412673  [  768/ 2130]
# loss: 0.688595  [  783/ 2130]
# loss: 0.498518  [  798/ 2130]
# loss: 0.442618  [  813/ 2130]
# loss: 0.685846  [  828/ 2130]
# loss: 0.695191  [  843/ 2130]
# loss: 0.466989  [  858/ 2130]
# loss: 0.565137  [  873/ 2130]
# loss: 0.424669  [  888/ 2130]
# loss: 0.390269  [  903/ 2130]
# loss: 0.833933  [  918/ 2130]
# loss: 0.399214  [  933/ 2130]
# loss: 0.424342  [  948/ 2130]
# loss: 0.478666  [  963/ 2130]
# loss: 0.410757  [  978/ 2130]
# loss: 0.423474  [  993/ 2130]
# loss: 0.461084  [ 1008/ 2130]
# loss: 0.794987  [ 1023/ 2130]
# loss: 0.526898  [ 1038/ 2130]
# loss: 0.475354  [ 1053/ 2130]
# loss: 0.535881  [ 1068/ 2130]
# loss: 0.520734  [ 1083/ 2130]
# loss: 0.469201  [ 1098/ 2130]
# loss: 0.596590  [ 1113/ 2130]
# loss: 0.485170  [ 1128/ 2130]
# loss: 0.481125  [ 1143/ 2130]
# loss: 0.509167  [ 1158/ 2130]
# loss: 0.373808  [ 1173/ 2130]
# loss: 0.758319  [ 1188/ 2130]
# loss: 0.523240  [ 1203/ 2130]
# loss: 0.372628  [ 1218/ 2130]
# loss: 0.432957  [ 1233/ 2130]
# loss: 0.400841  [ 1248/ 2130]
# loss: 0.886745  [ 1263/ 2130]
# loss: 0.552470  [ 1278/ 2130]
# loss: 0.511553  [ 1293/ 2130]
# loss: 0.516699  [ 1308/ 2130]
# loss: 0.510156  [ 1323/ 2130]
# loss: 0.560661  [ 1338/ 2130]
# loss: 0.404139  [ 1353/ 2130]
# loss: 0.341943  [ 1368/ 2130]
# loss: 0.460674  [ 1383/ 2130]
# loss: 0.439438  [ 1398/ 2130]
# loss: 0.471279  [ 1413/ 2130]
# loss: 0.574229  [ 1428/ 2130]
# loss: 0.656948  [ 1443/ 2130]
# loss: 0.500237  [ 1458/ 2130]
# loss: 0.618157  [ 1473/ 2130]
# loss: 0.468850  [ 1488/ 2130]
# loss: 0.359989  [ 1503/ 2130]
# loss: 0.439986  [ 1518/ 2130]
# loss: 0.456949  [ 1533/ 2130]
# loss: 0.461173  [ 1548/ 2130]
# loss: 0.619073  [ 1563/ 2130]
# loss: 0.622502  [ 1578/ 2130]
# loss: 0.615759  [ 1593/ 2130]
# loss: 0.456088  [ 1608/ 2130]
# loss: 0.481682  [ 1623/ 2130]
# loss: 0.474896  [ 1638/ 2130]
# loss: 0.387404  [ 1653/ 2130]
# loss: 0.376620  [ 1668/ 2130]
# loss: 0.776180  [ 1683/ 2130]
# loss: 0.400765  [ 1698/ 2130]
# loss: 0.438130  [ 1713/ 2130]
# loss: 0.304333  [ 1728/ 2130]
# loss: 0.706375  [ 1743/ 2130]
# loss: 0.433708  [ 1758/ 2130]
# loss: 0.376330  [ 1773/ 2130]
# loss: 0.351916  [ 1788/ 2130]
# loss: 0.385521  [ 1803/ 2130]
# loss: 0.255197  [ 1818/ 2130]
# loss: 0.429871  [ 1833/ 2130]
# loss: 0.550442  [ 1848/ 2130]
# loss: 0.301604  [ 1863/ 2130]
# loss: 0.594904  [ 1878/ 2130]
# loss: 0.541212  [ 1893/ 2130]
# loss: 0.587754  [ 1908/ 2130]
# loss: 1.607011  [ 1923/ 2130]
# loss: 0.735619  [ 1938/ 2130]
# loss: 0.555693  [ 1953/ 2130]
# loss: 0.357863  [ 1968/ 2130]
# loss: 1.054571  [ 1983/ 2130]
# loss: 0.439919  [ 1998/ 2130]
# loss: 0.726975  [ 2013/ 2130]
# loss: 0.385855  [ 2028/ 2130]
# loss: 0.439573  [ 2043/ 2130]
# loss: 0.294882  [ 2058/ 2130]
# loss: 0.433152  [ 2073/ 2130]
# loss: 0.486806  [ 2088/ 2130]
# loss: 0.735289  [ 2103/ 2130]
# loss: 0.685783  [ 2118/ 2130]
# Validation mIOU is: 0.4434330261927455
# Epoch 10
# -------------------------------
# loss: 0.432616  [    3/ 2130]
# loss: 0.505093  [   18/ 2130]
# loss: 0.610403  [   33/ 2130]
# loss: 0.515813  [   48/ 2130]
# loss: 0.492302  [   63/ 2130]
# loss: 0.536495  [   78/ 2130]
# loss: 0.885397  [   93/ 2130]
# loss: 0.462325  [  108/ 2130]
# loss: 0.671837  [  123/ 2130]
# loss: 0.479498  [  138/ 2130]
# loss: 0.500517  [  153/ 2130]
# loss: 0.472123  [  168/ 2130]
# loss: 0.435057  [  183/ 2130]
# loss: 0.396414  [  198/ 2130]
# loss: 0.548388  [  213/ 2130]
# loss: 0.645140  [  228/ 2130]
# loss: 0.432515  [  243/ 2130]
# loss: 0.432187  [  258/ 2130]
# loss: 0.511509  [  273/ 2130]
# loss: 0.571293  [  288/ 2130]
# loss: 0.485970  [  303/ 2130]
# loss: 0.604869  [  318/ 2130]
# loss: 0.337494  [  333/ 2130]
# loss: 0.438131  [  348/ 2130]
# loss: 0.454913  [  363/ 2130]
# loss: 0.439516  [  378/ 2130]
# loss: 0.950920  [  393/ 2130]
# loss: 0.878267  [  408/ 2130]
# loss: 0.587586  [  423/ 2130]
# loss: 0.627598  [  438/ 2130]
# loss: 1.073008  [  453/ 2130]
# loss: 0.564145  [  468/ 2130]
# loss: 0.479034  [  483/ 2130]
# loss: 0.743563  [  498/ 2130]
# loss: 0.401092  [  513/ 2130]
# loss: 0.400102  [  528/ 2130]
# loss: 0.557227  [  543/ 2130]
# loss: 0.458251  [  558/ 2130]
# loss: 0.645004  [  573/ 2130]
# loss: 1.198683  [  588/ 2130]
# loss: 0.394128  [  603/ 2130]
# loss: 0.610533  [  618/ 2130]
# loss: 0.561652  [  633/ 2130]
# loss: 0.434920  [  648/ 2130]
# loss: 0.577734  [  663/ 2130]
# loss: 0.428043  [  678/ 2130]
# loss: 0.432505  [  693/ 2130]
# loss: 0.692881  [  708/ 2130]
# loss: 0.381815  [  723/ 2130]
# loss: 0.390350  [  738/ 2130]
# loss: 0.532649  [  753/ 2130]
# loss: 0.480797  [  768/ 2130]
# loss: 0.574955  [  783/ 2130]
# loss: 0.292365  [  798/ 2130]
# loss: 0.627297  [  813/ 2130]
# loss: 0.403343  [  828/ 2130]
# loss: 0.364219  [  843/ 2130]
# loss: 0.963012  [  858/ 2130]
# loss: 0.534601  [  873/ 2130]
# loss: 0.899025  [  888/ 2130]
# loss: 0.407316  [  903/ 2130]
# loss: 0.471078  [  918/ 2130]
# loss: 1.088565  [  933/ 2130]
# loss: 0.368408  [  948/ 2130]
# loss: 0.433030  [  963/ 2130]
# loss: 0.477212  [  978/ 2130]
# loss: 0.623217  [  993/ 2130]
# loss: 0.480871  [ 1008/ 2130]
# loss: 0.540990  [ 1023/ 2130]
# loss: 0.315820  [ 1038/ 2130]
# loss: 0.484062  [ 1053/ 2130]
# loss: 0.338249  [ 1068/ 2130]
# loss: 0.271510  [ 1083/ 2130]
# loss: 0.400804  [ 1098/ 2130]
# loss: 0.449430  [ 1113/ 2130]
# loss: 0.466184  [ 1128/ 2130]
# loss: 0.479700  [ 1143/ 2130]
# loss: 0.583011  [ 1158/ 2130]
# loss: 0.408122  [ 1173/ 2130]
# loss: 0.840670  [ 1188/ 2130]
# loss: 1.719780  [ 1203/ 2130]
# loss: 0.518782  [ 1218/ 2130]
# loss: 0.362932  [ 1233/ 2130]
# loss: 0.667013  [ 1248/ 2130]
# loss: 1.124660  [ 1263/ 2130]
# loss: 0.603620  [ 1278/ 2130]
# loss: 0.481375  [ 1293/ 2130]
# loss: 0.500124  [ 1308/ 2130]
# loss: 0.590766  [ 1323/ 2130]
# loss: 0.507752  [ 1338/ 2130]
# loss: 0.576455  [ 1353/ 2130]
# loss: 0.391357  [ 1368/ 2130]
# loss: 0.492056  [ 1383/ 2130]
# loss: 0.573104  [ 1398/ 2130]
# loss: 0.543803  [ 1413/ 2130]
# loss: 0.643826  [ 1428/ 2130]
# loss: 0.406276  [ 1443/ 2130]
# loss: 0.403045  [ 1458/ 2130]
# loss: 0.566493  [ 1473/ 2130]
# loss: 0.460165  [ 1488/ 2130]
# loss: 0.385711  [ 1503/ 2130]
# loss: 0.508001  [ 1518/ 2130]
# loss: 0.553696  [ 1533/ 2130]
# loss: 0.539567  [ 1548/ 2130]
# loss: 0.697177  [ 1563/ 2130]
# loss: 0.471131  [ 1578/ 2130]
# loss: 0.663714  [ 1593/ 2130]
# loss: 0.987073  [ 1608/ 2130]
# loss: 0.404457  [ 1623/ 2130]
# loss: 0.523331  [ 1638/ 2130]
# loss: 0.522299  [ 1653/ 2130]
# loss: 0.371843  [ 1668/ 2130]
# loss: 0.513203  [ 1683/ 2130]
# loss: 0.481453  [ 1698/ 2130]
# loss: 0.308215  [ 1713/ 2130]
# loss: 0.510191  [ 1728/ 2130]
# loss: 0.509346  [ 1743/ 2130]
# loss: 0.412228  [ 1758/ 2130]
# loss: 0.644852  [ 1773/ 2130]
# loss: 0.462344  [ 1788/ 2130]
# loss: 0.412543  [ 1803/ 2130]
# loss: 0.428186  [ 1818/ 2130]
# loss: 0.535248  [ 1833/ 2130]
# loss: 0.796642  [ 1848/ 2130]
# loss: 0.444977  [ 1863/ 2130]
# loss: 0.320665  [ 1878/ 2130]
# loss: 0.446342  [ 1893/ 2130]
# loss: 0.432497  [ 1908/ 2130]
# loss: 0.436881  [ 1923/ 2130]
# loss: 0.713573  [ 1938/ 2130]
# loss: 0.734006  [ 1953/ 2130]
# loss: 0.670476  [ 1968/ 2130]
# loss: 0.659986  [ 1983/ 2130]
# loss: 0.480231  [ 1998/ 2130]
# loss: 0.394170  [ 2013/ 2130]
# loss: 0.623630  [ 2028/ 2130]
# loss: 0.397900  [ 2043/ 2130]
# loss: 0.542727  [ 2058/ 2130]
# loss: 0.685668  [ 2073/ 2130]
# loss: 0.437199  [ 2088/ 2130]
# loss: 0.458098  [ 2103/ 2130]
# loss: 0.545233  [ 2118/ 2130]
# Validation mIOU is: 0.45647836007165377
# new best iou: 0.45647836007165377
# Done!
# loading best saved model
# <All keys matched successfully>

# %% [markdown]
# The following cells will plot training loss vs Epoch and mean IOU vs Epoch

# %%
plt.title('Experiment 4 Part 1, Loss, Park 2313134')
for i in range(len(train_loss_list)):
    train_loss_list[i]=train_loss_list[i].detach().cpu()
plt.plot(epoch_list,train_loss_list)
plt.xlabel("Epoch")
plt.ylabel("Average Epoch Training Loss")
# Out:
# Text(0, 0.5, 'Average Epoch Training Loss')

# %%
plt.title('Experiment 4 Part 1, Validation, Park 2313134')
plt.plot(epoch_list,iou_list)
plt.xlabel("Epoch")
plt.ylabel("Validation IOU")
# Out:
# Text(0, 0.5, 'Validation IOU')

# %% [markdown]
# # Submission Instructions:
# <br>Run the following cells to generate the Testing Labels used for your submission on Kaggle
# <br>Do NOT edit any of the below cells
# <br>You can view the generated images from your moddel in the test_component folder
# <br>Use the excel file in the kaggle folder to submit on kaggle

# %%
class TestComponentCustomDataset(Dataset):
    def __init__(self, train_df,images_path):
        super(TestComponentCustomDataset, self).__init__()
        self.csv_path = train_csv_path
        self.image_path = images_path
        self.train_df = train_df
        self.trans= transforms.Compose([transforms.ToTensor()])


    def __getitem__(self, index):
        #x is the input
        #y is the label

        random_img_name=self.train_df.iloc[index].values[0]

        x = Image.open(os.path.join(self.image_path,random_img_name))
        x = self.trans(x)

        return x,random_img_name

    def __len__(self):
        return self.train_df.shape[0]

test_df=pd.read_csv(test_csv_path,header=None,index_col=None,delimiter=',')
test_comp_dataset = TestComponentCustomDataset(test_df,image_path)
test_comp_dataloader = DataLoader(test_comp_dataset,batch_size=1,shuffle=False)

imgPal = Image.open(os.path.join(label_path,"A10001.png"))
pal = imgPal.getpalette()

# %%
model.eval()
for batch,(x,img_name) in enumerate(test_comp_dataloader):
    print(img_name[0])
    y=model(x.to(device))
    preds=y[0]
    torch_hot_y=torch.argmax(preds,dim=0,keepdim=False)
    output = torch_hot_y.cpu().numpy().astype('uint8')
    output = np.where(output == 7, 100, output)
    output = Image.fromarray(output)
    output = output.convert('P')
    output.putpalette(pal)
    output.save(os.path.join(main_path,"test_component",img_name[0]))
component2kagglefn(test_csv_path,os.path.join(main_path,"test_component"))
# Out:
# A20400.png
# A20401.png
# A20402.png
# A20403.png
# A20404.png
# A20405.png
# A20406.png
# A20407.png
# A20408.png
# A20409.png
# A20410.png
# A20411.png
# A20412.png
# A20413.png
# A20414.png
# A20415.png
# A20416.png
# A20417.png
# A20418.png
# A20419.png
# A20420.png
# A20421.png
# A20422.png
# A20423.png
# A20424.png
# A20425.png
# A20426.png
# A20427.png
# A20428.png
# A20429.png
# A20430.png
# A20431.png
# A20432.png
# A20433.png
# A20434.png
# A20435.png
# A20436.png
# A20437.png
# A20438.png
# A20439.png
# A20440.png
# A20441.png
# A20442.png
# A20443.png
# A20444.png
# A20445.png
# A20446.png
# A20447.png
# A20448.png
# A20449.png
# A20450.png
# A20451.png
# A20452.png
# A20453.png
# A20454.png
# A20455.png
# A20456.png
# A20457.png
# A20458.png
# A20459.png
# A20460.png
# A20461.png
# A20462.png
# A20463.png
# A20464.png
# A20465.png
# A20466.png
# A20467.png
# A20468.png
# A20469.png
# A20470.png
# A20471.png
# A20472.png
# A20473.png
# A20474.png
# A20475.png
# A20476.png
# A20477.png
# A20478.png
# A20479.png
# A20480.png
# A20481.png
# A20482.png
# A20483.png
# A20484.png
# A20485.png
# A20486.png
# A20487.png
# A20488.png
# A20489.png
# A20490.png
# A20491.png
# A20492.png
# A20493.png
# A20494.png
# A20495.png
# A20496.png
# A20497.png
# A20498.png
# A20499.png
# A20500.png
# A20501.png
# A20502.png
# A20503.png
# A20504.png
# A20505.png
# A20506.png
# A20507.png
# A20508.png
# A20509.png
# A20510.png
# A20511.png
# A20512.png
# A20513.png
# A20514.png
# A20515.png
# A20516.png
# A20517.png
# A20518.png
# A20519.png
# A20520.png
# A20521.png
# A20522.png
# A20523.png
# A20524.png
# A20525.png
# A20526.png
# A20527.png
# A20528.png
# A20529.png
# A20530.png
# A20531.png
# A20532.png
# A20533.png
# A20534.png
# A20535.png
# A20536.png
# A20537.png
# A20538.png
# A20539.png
# A20540.png
# A20541.png
# A20542.png
# A20543.png
# A20544.png
# A20545.png
# A20546.png
# A20547.png
# A20548.png
# A20549.png
# A20550.png
# A20551.png
# A20552.png
# A20553.png
# A20554.png
# A20555.png
# A20556.png
# A20557.png
# A20558.png
# A20559.png
# A20560.png
# A20561.png
# A20562.png
# A20563.png
# A20564.png
# A20565.png
# A20566.png
# A20567.png
# A20568.png
# A20569.png
# A20570.png
# A20571.png
# A20572.png
# A20573.png
# A20574.png
# A20575.png
# A20576.png
# A20577.png
# A20578.png
# A20579.png
# A20580.png
# A20581.png
# A20582.png
# A20583.png
# A20584.png
# A20585.png
# A20586.png
# A20587.png
# A20588.png
# A20589.png
# A20590.png
# A20591.png
# A20592.png
# A20593.png
# A20594.png
# A20595.png
# A20596.png
# A20597.png
# A20598.png
# A20599.png
# A30001.png
# A30002.png
# A30003.png
# A30004.png
# A30005.png
# A30006.png
# A30007.png
# A30008.png
# A30009.png
# A30010.png
# A30011.png
# A30012.png
# A30013.png
# A30014.png
# A30015.png
# A30016.png
# A30017.png
# A30018.png
# A30019.png
# A30020.png
# A30021.png
# A30022.png
# A30023.png
# A30024.png
# A30025.png
# A30026.png
# A30027.png
# A30028.png
# A30029.png
# A30030.png
# A30031.png
# A30032.png
# A30033.png
# A30034.png
# A30035.png
# A30036.png
# A30037.png
# A30038.png
# A30039.png
# A30040.png
# A30041.png
# A30042.png
# A30043.png
# A30044.png
# A30045.png
# A30046.png
# A30047.png
# A30048.png
# A30049.png
# A30050.png
# A30051.png
# A30052.png
# A30053.png
# A30054.png
# A30055.png
# A30056.png
# A30057.png
# A30058.png
# A30059.png
# A30060.png
# A30061.png
# A30062.png
# A30063.png
# A30064.png
# A30065.png
# A30066.png
# A30067.png
# A30068.png
# A30069.png
# A30070.png
# A30071.png
# A30072.png
# A30073.png
# A30074.png
# A30075.png
# A30076.png
# A30077.png
# A30078.png
# A30079.png
# A30080.png
# A30081.png
# A30082.png
# A30083.png
# A30084.png
# A30085.png
# A30086.png
# A30087.png
# A30088.png
# A30089.png
# A30090.png
# A30091.png
# A30092.png
# A30093.png
# A30094.png
# A30095.png
# A30096.png
# A30097.png
# A30098.png
# A30099.png
# A30100.png
# A50001.png
# A50002.png
# A50003.png
# A50004.png
# A50005.png
# A50006.png
# A50007.png
# A50008.png
# A50009.png
# A50010.png
# A50011.png
# A50012.png
# A50013.png
# A50014.png
# A50015.png
# A50016.png
# A50017.png
# A50018.png
# A50019.png
# A50020.png
# A50021.png
# A50022.png
# A50023.png
# A50024.png
# A50025.png
# A50026.png
# A50027.png
# A50028.png
# A50029.png
# A50030.png
# A50031.png
# A50032.png
# A50033.png
# A50034.png
# A50035.png
# A50036.png
# A50037.png
# A50038.png
# A50039.png
# A50040.png
# A50041.png
# A50042.png
# A50043.png
# A50044.png
# A50045.png
# A50046.png
# A50047.png
# A50048.png
# A50049.png
# A50050.png
# A50051.png
# A50052.png
# A50053.png
# A50054.png
# A50055.png
# A50056.png
# A50057.png
# A50058.png
# A50059.png
# A50060.png
# A50061.png
# A50062.png
# A50063.png
# A50064.png
# A50065.png
# A50066.png
# A50067.png
# A50068.png
# A50069.png
# A50070.png
# A50071.png
# A50072.png
# A50073.png
# A50074.png
# A50075.png
# A50076.png
# A50077.png
# A50078.png
# A50079.png
# A50080.png
# A50081.png
# A50082.png
# A50083.png
# A50084.png
# A50085.png
# A50086.png
# A50087.png
# A50088.png
# A50089.png
# A50090.png
# A50091.png
# A50092.png
# A50093.png
# A50094.png
# A50095.png
# A50096.png
# A50097.png
# A50098.png
# A50099.png
# A50100.png
# A50101.png
# A50102.png
# A50103.png
# A50104.png
# A50105.png
# A50106.png
# A50107.png
# A50108.png
# A50109.png
# A50110.png
# A50111.png
# A50112.png
# A50113.png
# A50114.png
# A50115.png
# A50116.png
# A50117.png
# A50118.png
# A50119.png
# A50120.png
# A50121.png
# A50122.png
# A50123.png
# A50124.png
# A50125.png
# A50126.png
# A50127.png
# A50128.png
# A50129.png
# A50130.png
# A50131.png
# A50132.png
# A50133.png
# A50134.png
# A50135.png
# A50136.png
# A50137.png
# A50138.png
# A50139.png
# A50140.png
# A50141.png
# A50142.png
# A50143.png
# A50144.png
# A50145.png
# A50146.png
# A50147.png
# A50148.png
# A50149.png
# A50150.png
# A50151.png
# A50152.png
# A50153.png
# A50154.png
# A50155.png
# A50156.png
# A50157.png
# A50158.png
# A50159.png
# A50160.png
# A50161.png
# A50162.png
# A50163.png
# A50164.png
# A50165.png
# A50166.png
# A50167.png
# A50168.png
# A50169.png
# A50170.png
# A50171.png
# A50172.png
# A50173.png
# A50174.png
# A50175.png
# A50176.png
# A50177.png
# A50178.png
# A50179.png
# A50180.png
# A50181.png
# A50182.png
# A50183.png
# A50184.png
# A50185.png
# A50186.png
# A50187.png
# A50188.png
# A50189.png
# A50190.png
# A50191.png
# A50192.png
# A50193.png
# A50194.png
# A50195.png
# A50196.png
# A50197.png
# A50198.png
# A50199.png
# A50200.png
# A50201.png
# A50202.png
# A50203.png
# A50204.png
# A50205.png
# A50206.png
# A50207.png
# A50208.png
# A50209.png
# A50210.png
# A50211.png
# A50212.png
# A50213.png
# A50214.png
# A50215.png
# A50216.png
# A50217.png
# A50218.png
# A50219.png
# A50220.png
# A50221.png
# A50222.png
# A50223.png
# A50224.png
# A50225.png
# A50226.png
# A50227.png
# A50228.png
# A50229.png
# A50230.png
# A50231.png
# A50232.png
# A50233.png
# A50234.png
# A50235.png
# A50236.png
# A50237.png
# A50238.png
# A50239.png
# A50240.png
# A50241.png
# A50242.png
# A50243.png
# A50244.png
# A50245.png
# A50246.png
# A50247.png
# A50248.png
# A50249.png
# A50250.png
# A50251.png
# A50252.png
# A50253.png
# A50254.png
# A50255.png
# A50256.png
# A50257.png
# A50258.png
# A50259.png
# A50260.png
# A50261.png
# A50262.png
# A50263.png
# A50264.png
# A50265.png
# A50266.png
# A50267.png
# A50268.png
# A50269.png
# A50270.png
# A50271.png
# A50272.png
# A50273.png
# A50274.png
# A50275.png
# A50276.png
# A50277.png
# A50278.png
# A50279.png
# A50280.png
# A50281.png
# A50282.png
# A50283.png
# A50284.png
# A50285.png
# A50286.png
# A50287.png
# A50288.png
# A50289.png
# A50290.png
# A50291.png
# A50292.png
# A50293.png
# A50294.png
# A50295.png
# A50296.png
# A50297.png
# A50298.png
# A50299.png
# A50300.png
# A50301.png
# A50302.png
# A50303.png
# A50304.png
# A50305.png
# A50306.png
# A50307.png
# A50308.png
# A50309.png
# A50310.png
# A50311.png
# A50312.png
# A50313.png
# A50314.png
# A50315.png
# A50316.png
# A50317.png
# A50318.png
# A50319.png
# A50320.png
# A50321.png
# A50322.png
# A50323.png
# A50324.png
# A50325.png
# A50326.png
# A50327.png
# A50328.png
# A50329.png
# A50330.png
# A50331.png
# A50332.png
# A50333.png
# A50334.png
# A50335.png
# A50336.png
# A50337.png
# A50338.png
# A50339.png
# A50340.png
# A50341.png
# A50342.png
# A50343.png
# A50344.png
# A50345.png
# A50346.png
# A50347.png
# A50348.png
# A50349.png
# A50350.png
# A50351.png
# A50352.png
# A50353.png
# A50354.png
# A50355.png
# A50356.png
# A50357.png
# A50358.png
# A50359.png
# B20025.png
# B20026.png
# B20027.png
# B20028.png
# B20029.png
# B20030.png
# B20031.png
# B20032.png
# B20033.png
# B20034.png
# B20035.png
# B20036.png
# B20037.png
# B20038.png
# B20039.png
# B20040.png
# B20041.png
# B20042.png
# B20043.png
# B20044.png
# B20045.png
# B20046.png
# B20047.png
# B20048.png
# B20049.png
# B20050.png
# B50001.png
# B50002.png
# B50003.png
# B50004.png
# B50005.png
# B50006.png
# B50007.png
# B50008.png
# B50009.png
# B50010.png
# B50011.png
# B50012.png
# B50013.png
# B50014.png
# B50015.png
# B50016.png
# B50017.png
# B50018.png
# B50019.png
# B50020.png
# B50021.png
# B50022.png
# B50023.png
# B50024.png
# B50025.png
# B50026.png
# B50027.png
# B50028.png
# B50029.png
# B50030.png
# B50031.png
# B50032.png
# B50033.png
# B50034.png
# B50035.png
# B50036.png
# B50037.png
# B50038.png
# B50039.png
# B50040.png
# B50041.png
# B50042.png
# B50043.png
# B50044.png
# B50045.png
# B50046.png
# B50047.png
# B50048.png
# B50049.png
# B50050.png
# B50051.png
# B50052.png
# B50053.png
# B50054.png
# B50055.png
# B50056.png
# B50057.png
# B50058.png
# B50059.png
# B50060.png
# B50061.png
# B50062.png
# B50063.png
# B50064.png
# B50065.png
# B50066.png
# B50067.png
# B50068.png
# B50069.png
# B50070.png
# B50071.png
# B50072.png
# B50073.png
# B50074.png
# B50075.png
# B50076.png
# B50077.png
# B50078.png
# B50079.png
# B50080.png
# B50081.png
# B50082.png
# B50083.png
# B50084.png
# B50085.png
# B50086.png
# B50087.png
# B50088.png
# B50089.png
# B50090.png
# B50091.png
# B50092.png
# B50093.png
# B50094.png
# B50095.png
# B50096.png
# B50097.png
# B50098.png
# B50099.png
# B50100.png
# B50101.png
# B50102.png
# B50103.png
# B50104.png
# B50105.png
# B50106.png
# B50107.png
# B50108.png
# B50109.png
# B50110.png
# B50111.png
# B50112.png
# B50113.png
# B50114.png
# B50115.png
# B50116.png
# B50117.png
# B50118.png
# B50119.png
# B50120.png
# B50121.png
# B50122.png
# B50123.png
# B50124.png
# B50125.png
# B50126.png
# B50127.png
# B50128.png
# B50129.png
# B50130.png
# B50131.png
# B50132.png
# B50133.png
# B50134.png
# B50135.png
# B50136.png
# B50137.png
# B50138.png
# B50139.png
# B50140.png
# B50141.png
# B50142.png
# B50143.png
# B50144.png
# B50145.png
# B50146.png
# B50147.png
# B50148.png
# B50149.png
# B50150.png
# B50151.png
# B50152.png
# B50153.png
# B50154.png
# B50155.png
# B50156.png
# B50157.png
# B50158.png
# B50159.png
# B50160.png
# B50161.png
# B50162.png
# B50163.png
# B50164.png
# B50165.png
# B50166.png
# B50167.png
# B50168.png
# B50169.png
# B50170.png
# B50171.png
# B50172.png
# B50173.png
# B50174.png
# B50175.png
# B50176.png
# B50177.png
# B50178.png
# B50179.png
# B50180.png
# B50181.png
# B50182.png
# B50183.png
# B50184.png
# B50185.png
# B50186.png
# B50187.png
# B50188.png
# B50189.png
# B50190.png
# B50191.png
# B50192.png
# B50193.png
# B50194.png
# B50195.png
# B50196.png
# B50197.png
# B50198.png
# B50199.png
# B50200.png
# B50201.png
# B50202.png
# B50203.png
# B50204.png
# B50205.png
# B50206.png
# B50207.png
# B50208.png
# B50209.png
# B50210.png
# B50211.png
# B50212.png
# B50213.png
# B50214.png
# B50215.png
# B50216.png
# B50217.png
# B50218.png
# B50219.png
# B50220.png
# B50221.png
# B50222.png
# B50223.png
# B50224.png
# B50225.png
# B50226.png
# B50227.png
# B50228.png
# B50229.png
# B50230.png
# B50231.png
# B50232.png
# B50233.png
# B50234.png
# B50235.png
# B50236.png
# B50237.png
# B50238.png
# B50239.png
# B50240.png
# B50241.png
# B50242.png
# B50243.png
# B50244.png
# B50245.png
# B50246.png
# B50247.png
# B50248.png
# B50249.png
# B50250.png
# B50251.png
# B50252.png
# B50253.png
# B50254.png
# B50255.png
# B50256.png
# B50257.png
# B50258.png
# B50259.png
# B50260.png
# B50261.png
# B50262.png
# B50263.png
# B50264.png
# B50265.png
# B50266.png
# B50267.png
# B50268.png
# B50269.png
# B50270.png
# B50271.png
# B50272.png
# B50273.png
# B50274.png
# B50275.png
# B50276.png
# B50277.png
# B50278.png
# B50279.png
# B50280.png
# B50281.png
# B50282.png
# B50283.png
# B50284.png
# B50285.png
# B50286.png
# B50287.png
# B50288.png
# B50289.png
# B50290.png
# B50291.png
# B50292.png
# B50293.png
# B50294.png
# B50295.png
# B50296.png
# B50297.png
# B50298.png
# B50299.png
# B50300.png
# B50301.png
# B50302.png
# B50303.png
# B50304.png
# B50305.png
# B50306.png
# B50307.png
# B50308.png
# B50309.png
# B50310.png
# B50311.png
# B50312.png
# B50313.png
# B50314.png
# B50315.png
# B50316.png
# B50317.png
# B50318.png
# B50319.png
# updated
# component 1: A20400.png
# component 2: A20401.png
# component 3: A20402.png
# component 4: A20403.png
# component 5: A20404.png
# component 6: A20405.png
# component 7: A20406.png
# component 8: A20407.png
# component 9: A20408.png
# component 10: A20409.png
# component 11: A20410.png
# component 12: A20411.png
# component 13: A20412.png
# component 14: A20413.png
# component 15: A20414.png
# component 16: A20415.png
# component 17: A20416.png
# component 18: A20417.png
# component 19: A20418.png
# component 20: A20419.png
# component 21: A20420.png
# component 22: A20421.png
# component 23: A20422.png
# component 24: A20423.png
# component 25: A20424.png
# component 26: A20425.png
# component 27: A20426.png
# component 28: A20427.png
# component 29: A20428.png
# component 30: A20429.png
# component 31: A20430.png
# component 32: A20431.png
# component 33: A20432.png
# component 34: A20433.png
# component 35: A20434.png
# component 36: A20435.png
# component 37: A20436.png
# component 38: A20437.png
# component 39: A20438.png
# component 40: A20439.png
# component 41: A20440.png
# component 42: A20441.png
# component 43: A20442.png
# component 44: A20443.png
# component 45: A20444.png
# component 46: A20445.png
# component 47: A20446.png
# component 48: A20447.png
# component 49: A20448.png
# component 50: A20449.png
# component 51: A20450.png
# component 52: A20451.png
# component 53: A20452.png
# component 54: A20453.png
# component 55: A20454.png
# component 56: A20455.png
# component 57: A20456.png
# component 58: A20457.png
# component 59: A20458.png
# component 60: A20459.png
# component 61: A20460.png
# component 62: A20461.png
# component 63: A20462.png
# component 64: A20463.png
# component 65: A20464.png
# component 66: A20465.png
# component 67: A20466.png
# component 68: A20467.png
# component 69: A20468.png
# component 70: A20469.png
# component 71: A20470.png
# component 72: A20471.png
# component 73: A20472.png
# component 74: A20473.png
# component 75: A20474.png
# component 76: A20475.png
# component 77: A20476.png
# component 78: A20477.png
# component 79: A20478.png
# component 80: A20479.png
# component 81: A20480.png
# component 82: A20481.png
# component 83: A20482.png
# component 84: A20483.png
# component 85: A20484.png
# component 86: A20485.png
# component 87: A20486.png
# component 88: A20487.png
# component 89: A20488.png
# component 90: A20489.png
# component 91: A20490.png
# component 92: A20491.png
# component 93: A20492.png
# component 94: A20493.png
# component 95: A20494.png
# component 96: A20495.png
# component 97: A20496.png
# component 98: A20497.png
# component 99: A20498.png
# component 100: A20499.png
# component 101: A20500.png
# component 102: A20501.png
# component 103: A20502.png
# component 104: A20503.png
# component 105: A20504.png
# component 106: A20505.png
# component 107: A20506.png
# component 108: A20507.png
# component 109: A20508.png
# component 110: A20509.png
# component 111: A20510.png
# component 112: A20511.png
# component 113: A20512.png
# component 114: A20513.png
# component 115: A20514.png
# component 116: A20515.png
# component 117: A20516.png
# component 118: A20517.png
# component 119: A20518.png
# component 120: A20519.png
# component 121: A20520.png
# component 122: A20521.png
# component 123: A20522.png
# component 124: A20523.png
# component 125: A20524.png
# component 126: A20525.png
# component 127: A20526.png
# component 128: A20527.png
# component 129: A20528.png
# component 130: A20529.png
# component 131: A20530.png
# component 132: A20531.png
# component 133: A20532.png
# component 134: A20533.png
# component 135: A20534.png
# component 136: A20535.png
# component 137: A20536.png
# component 138: A20537.png
# component 139: A20538.png
# component 140: A20539.png
# component 141: A20540.png
# component 142: A20541.png
# component 143: A20542.png
# component 144: A20543.png
# component 145: A20544.png
# component 146: A20545.png
# component 147: A20546.png
# component 148: A20547.png
# component 149: A20548.png
# component 150: A20549.png
# component 151: A20550.png
# component 152: A20551.png
# component 153: A20552.png
# component 154: A20553.png
# component 155: A20554.png
# component 156: A20555.png
# component 157: A20556.png
# component 158: A20557.png
# component 159: A20558.png
# component 160: A20559.png
# component 161: A20560.png
# component 162: A20561.png
# component 163: A20562.png
# component 164: A20563.png
# component 165: A20564.png
# component 166: A20565.png
# component 167: A20566.png
# component 168: A20567.png
# component 169: A20568.png
# component 170: A20569.png
# component 171: A20570.png
# component 172: A20571.png
# component 173: A20572.png
# component 174: A20573.png
# component 175: A20574.png
# component 176: A20575.png
# component 177: A20576.png
# component 178: A20577.png
# component 179: A20578.png
# component 180: A20579.png
# component 181: A20580.png
# component 182: A20581.png
# component 183: A20582.png
# component 184: A20583.png
# component 185: A20584.png
# component 186: A20585.png
# component 187: A20586.png
# component 188: A20587.png
# component 189: A20588.png
# component 190: A20589.png
# component 191: A20590.png
# component 192: A20591.png
# component 193: A20592.png
# component 194: A20593.png
# component 195: A20594.png
# component 196: A20595.png
# component 197: A20596.png
# component 198: A20597.png
# component 199: A20598.png
# component 200: A20599.png
# component 201: A30001.png
# component 202: A30002.png
# component 203: A30003.png
# component 204: A30004.png
# component 205: A30005.png
# component 206: A30006.png
# component 207: A30007.png
# component 208: A30008.png
# component 209: A30009.png
# component 210: A30010.png
# component 211: A30011.png
# component 212: A30012.png
# component 213: A30013.png
# component 214: A30014.png
# component 215: A30015.png
# component 216: A30016.png
# component 217: A30017.png
# component 218: A30018.png
# component 219: A30019.png
# component 220: A30020.png
# component 221: A30021.png
# component 222: A30022.png
# component 223: A30023.png
# component 224: A30024.png
# component 225: A30025.png
# component 226: A30026.png
# component 227: A30027.png
# component 228: A30028.png
# component 229: A30029.png
# component 230: A30030.png
# component 231: A30031.png
# component 232: A30032.png
# component 233: A30033.png
# component 234: A30034.png
# component 235: A30035.png
# component 236: A30036.png
# component 237: A30037.png
# component 238: A30038.png
# component 239: A30039.png
# component 240: A30040.png
# component 241: A30041.png
# component 242: A30042.png
# component 243: A30043.png
# component 244: A30044.png
# component 245: A30045.png
# component 246: A30046.png
# component 247: A30047.png
# component 248: A30048.png
# component 249: A30049.png
# component 250: A30050.png
# component 251: A30051.png
# component 252: A30052.png
# component 253: A30053.png
# component 254: A30054.png
# component 255: A30055.png
# component 256: A30056.png
# component 257: A30057.png
# component 258: A30058.png
# component 259: A30059.png
# component 260: A30060.png
# component 261: A30061.png
# component 262: A30062.png
# component 263: A30063.png
# component 264: A30064.png
# component 265: A30065.png
# component 266: A30066.png
# component 267: A30067.png
# component 268: A30068.png
# component 269: A30069.png
# component 270: A30070.png
# component 271: A30071.png
# component 272: A30072.png
# component 273: A30073.png
# component 274: A30074.png
# component 275: A30075.png
# component 276: A30076.png
# component 277: A30077.png
# component 278: A30078.png
# component 279: A30079.png
# component 280: A30080.png
# component 281: A30081.png
# component 282: A30082.png
# component 283: A30083.png
# component 284: A30084.png
# component 285: A30085.png
# component 286: A30086.png
# component 287: A30087.png
# component 288: A30088.png
# component 289: A30089.png
# component 290: A30090.png
# component 291: A30091.png
# component 292: A30092.png
# component 293: A30093.png
# component 294: A30094.png
# component 295: A30095.png
# component 296: A30096.png
# component 297: A30097.png
# component 298: A30098.png
# component 299: A30099.png
# component 300: A30100.png
# component 301: A50001.png
# component 302: A50002.png
# component 303: A50003.png
# component 304: A50004.png
# component 305: A50005.png
# component 306: A50006.png
# component 307: A50007.png
# component 308: A50008.png
# component 309: A50009.png
# component 310: A50010.png
# component 311: A50011.png
# component 312: A50012.png
# component 313: A50013.png
# component 314: A50014.png
# component 315: A50015.png
# component 316: A50016.png
# component 317: A50017.png
# component 318: A50018.png
# component 319: A50019.png
# component 320: A50020.png
# component 321: A50021.png
# component 322: A50022.png
# component 323: A50023.png
# component 324: A50024.png
# component 325: A50025.png
# component 326: A50026.png
# component 327: A50027.png
# component 328: A50028.png
# component 329: A50029.png
# component 330: A50030.png
# component 331: A50031.png
# component 332: A50032.png
# component 333: A50033.png
# component 334: A50034.png
# component 335: A50035.png
# component 336: A50036.png
# component 337: A50037.png
# component 338: A50038.png
# component 339: A50039.png
# component 340: A50040.png
# component 341: A50041.png
# component 342: A50042.png
# component 343: A50043.png
# component 344: A50044.png
# component 345: A50045.png
# component 346: A50046.png
# component 347: A50047.png
# component 348: A50048.png
# component 349: A50049.png
# component 350: A50050.png
# component 351: A50051.png
# component 352: A50052.png
# component 353: A50053.png
# component 354: A50054.png
# component 355: A50055.png
# component 356: A50056.png
# component 357: A50057.png
# component 358: A50058.png
# component 359: A50059.png
# component 360: A50060.png
# component 361: A50061.png
# component 362: A50062.png
# component 363: A50063.png
# component 364: A50064.png
# component 365: A50065.png
# component 366: A50066.png
# component 367: A50067.png
# component 368: A50068.png
# component 369: A50069.png
# component 370: A50070.png
# component 371: A50071.png
# component 372: A50072.png
# component 373: A50073.png
# component 374: A50074.png
# component 375: A50075.png
# component 376: A50076.png
# component 377: A50077.png
# component 378: A50078.png
# component 379: A50079.png
# component 380: A50080.png
# component 381: A50081.png
# component 382: A50082.png
# component 383: A50083.png
# component 384: A50084.png
# component 385: A50085.png
# component 386: A50086.png
# component 387: A50087.png
# component 388: A50088.png
# component 389: A50089.png
# component 390: A50090.png
# component 391: A50091.png
# component 392: A50092.png
# component 393: A50093.png
# component 394: A50094.png
# component 395: A50095.png
# component 396: A50096.png
# component 397: A50097.png
# component 398: A50098.png
# component 399: A50099.png
# component 400: A50100.png
# component 401: A50101.png
# component 402: A50102.png
# component 403: A50103.png
# component 404: A50104.png
# component 405: A50105.png
# component 406: A50106.png
# component 407: A50107.png
# component 408: A50108.png
# component 409: A50109.png
# component 410: A50110.png
# component 411: A50111.png
# component 412: A50112.png
# component 413: A50113.png
# component 414: A50114.png
# component 415: A50115.png
# component 416: A50116.png
# component 417: A50117.png
# component 418: A50118.png
# component 419: A50119.png
# component 420: A50120.png
# component 421: A50121.png
# component 422: A50122.png
# component 423: A50123.png
# component 424: A50124.png
# component 425: A50125.png
# component 426: A50126.png
# component 427: A50127.png
# component 428: A50128.png
# component 429: A50129.png
# component 430: A50130.png
# component 431: A50131.png
# component 432: A50132.png
# component 433: A50133.png
# component 434: A50134.png
# component 435: A50135.png
# component 436: A50136.png
# component 437: A50137.png
# component 438: A50138.png
# component 439: A50139.png
# component 440: A50140.png
# component 441: A50141.png
# component 442: A50142.png
# component 443: A50143.png
# component 444: A50144.png
# component 445: A50145.png
# component 446: A50146.png
# component 447: A50147.png
# component 448: A50148.png
# component 449: A50149.png
# component 450: A50150.png
# component 451: A50151.png
# component 452: A50152.png
# component 453: A50153.png
# component 454: A50154.png
# component 455: A50155.png
# component 456: A50156.png
# component 457: A50157.png
# component 458: A50158.png
# component 459: A50159.png
# component 460: A50160.png
# component 461: A50161.png
# component 462: A50162.png
# component 463: A50163.png
# component 464: A50164.png
# component 465: A50165.png
# component 466: A50166.png
# component 467: A50167.png
# component 468: A50168.png
# component 469: A50169.png
# component 470: A50170.png
# component 471: A50171.png
# component 472: A50172.png
# component 473: A50173.png
# component 474: A50174.png
# component 475: A50175.png
# component 476: A50176.png
# component 477: A50177.png
# component 478: A50178.png
# component 479: A50179.png
# component 480: A50180.png
# component 481: A50181.png
# component 482: A50182.png
# component 483: A50183.png
# component 484: A50184.png
# component 485: A50185.png
# component 486: A50186.png
# component 487: A50187.png
# component 488: A50188.png
# component 489: A50189.png
# component 490: A50190.png
# component 491: A50191.png
# component 492: A50192.png
# component 493: A50193.png
# component 494: A50194.png
# component 495: A50195.png
# component 496: A50196.png
# component 497: A50197.png
# component 498: A50198.png
# component 499: A50199.png
# component 500: A50200.png
# component 501: A50201.png
# component 502: A50202.png
# component 503: A50203.png
# component 504: A50204.png
# component 505: A50205.png
# component 506: A50206.png
# component 507: A50207.png
# component 508: A50208.png
# component 509: A50209.png
# component 510: A50210.png
# component 511: A50211.png
# component 512: A50212.png
# component 513: A50213.png
# component 514: A50214.png
# component 515: A50215.png
# component 516: A50216.png
# component 517: A50217.png
# component 518: A50218.png
# component 519: A50219.png
# component 520: A50220.png
# component 521: A50221.png
# component 522: A50222.png
# component 523: A50223.png
# component 524: A50224.png
# component 525: A50225.png
# component 526: A50226.png
# component 527: A50227.png
# component 528: A50228.png
# component 529: A50229.png
# component 530: A50230.png
# component 531: A50231.png
# component 532: A50232.png
# component 533: A50233.png
# component 534: A50234.png
# component 535: A50235.png
# component 536: A50236.png
# component 537: A50237.png
# component 538: A50238.png
# component 539: A50239.png
# component 540: A50240.png
# component 541: A50241.png
# component 542: A50242.png
# component 543: A50243.png
# component 544: A50244.png
# component 545: A50245.png
# component 546: A50246.png
# component 547: A50247.png
# component 548: A50248.png
# component 549: A50249.png
# component 550: A50250.png
# component 551: A50251.png
# component 552: A50252.png
# component 553: A50253.png
# component 554: A50254.png
# component 555: A50255.png
# component 556: A50256.png
# component 557: A50257.png
# component 558: A50258.png
# component 559: A50259.png
# component 560: A50260.png
# component 561: A50261.png
# component 562: A50262.png
# component 563: A50263.png
# component 564: A50264.png
# component 565: A50265.png
# component 566: A50266.png
# component 567: A50267.png
# component 568: A50268.png
# component 569: A50269.png
# component 570: A50270.png
# component 571: A50271.png
# component 572: A50272.png
# component 573: A50273.png
# component 574: A50274.png
# component 575: A50275.png
# component 576: A50276.png
# component 577: A50277.png
# component 578: A50278.png
# component 579: A50279.png
# component 580: A50280.png
# component 581: A50281.png
# component 582: A50282.png
# component 583: A50283.png
# component 584: A50284.png
# component 585: A50285.png
# component 586: A50286.png
# component 587: A50287.png
# component 588: A50288.png
# component 589: A50289.png
# component 590: A50290.png
# component 591: A50291.png
# component 592: A50292.png
# component 593: A50293.png
# component 594: A50294.png
# component 595: A50295.png
# component 596: A50296.png
# component 597: A50297.png
# component 598: A50298.png
# component 599: A50299.png
# component 600: A50300.png
# component 601: A50301.png
# component 602: A50302.png
# component 603: A50303.png
# component 604: A50304.png
# component 605: A50305.png
# component 606: A50306.png
# component 607: A50307.png
# component 608: A50308.png
# component 609: A50309.png
# component 610: A50310.png
# component 611: A50311.png
# component 612: A50312.png
# component 613: A50313.png
# component 614: A50314.png
# component 615: A50315.png
# component 616: A50316.png
# component 617: A50317.png
# component 618: A50318.png
# component 619: A50319.png
# component 620: A50320.png
# component 621: A50321.png
# component 622: A50322.png
# component 623: A50323.png
# component 624: A50324.png
# component 625: A50325.png
# component 626: A50326.png
# component 627: A50327.png
# component 628: A50328.png
# component 629: A50329.png
# component 630: A50330.png
# component 631: A50331.png
# component 632: A50332.png
# component 633: A50333.png
# component 634: A50334.png
# component 635: A50335.png
# component 636: A50336.png
# component 637: A50337.png
# component 638: A50338.png
# component 639: A50339.png
# component 640: A50340.png
# component 641: A50341.png
# component 642: A50342.png
# component 643: A50343.png
# component 644: A50344.png
# component 645: A50345.png
# component 646: A50346.png
# component 647: A50347.png
# component 648: A50348.png
# component 649: A50349.png
# component 650: A50350.png
# component 651: A50351.png
# component 652: A50352.png
# component 653: A50353.png
# component 654: A50354.png
# component 655: A50355.png
# component 656: A50356.png
# component 657: A50357.png
# component 658: A50358.png
# component 659: A50359.png
# component 660: B20025.png
# component 661: B20026.png
# component 662: B20027.png
# component 663: B20028.png
# component 664: B20029.png
# component 665: B20030.png
# component 666: B20031.png
# component 667: B20032.png
# component 668: B20033.png
# component 669: B20034.png
# component 670: B20035.png
# component 671: B20036.png
# component 672: B20037.png
# component 673: B20038.png
# component 674: B20039.png
# component 675: B20040.png
# component 676: B20041.png
# component 677: B20042.png
# component 678: B20043.png
# component 679: B20044.png
# component 680: B20045.png
# component 681: B20046.png
# component 682: B20047.png
# component 683: B20048.png
# component 684: B20049.png
# component 685: B20050.png
# component 686: B50001.png
# component 687: B50002.png
# component 688: B50003.png
# component 689: B50004.png
# component 690: B50005.png
# component 691: B50006.png
# component 692: B50007.png
# component 693: B50008.png
# component 694: B50009.png
# component 695: B50010.png
# component 696: B50011.png
# component 697: B50012.png
# component 698: B50013.png
# component 699: B50014.png
# component 700: B50015.png
# component 701: B50016.png
# component 702: B50017.png
# component 703: B50018.png
# component 704: B50019.png
# component 705: B50020.png
# component 706: B50021.png
# component 707: B50022.png
# component 708: B50023.png
# component 709: B50024.png
# component 710: B50025.png
# component 711: B50026.png
# component 712: B50027.png
# component 713: B50028.png
# component 714: B50029.png
# component 715: B50030.png
# component 716: B50031.png
# component 717: B50032.png
# component 718: B50033.png
# component 719: B50034.png
# component 720: B50035.png
# component 721: B50036.png
# component 722: B50037.png
# component 723: B50038.png
# component 724: B50039.png
# component 725: B50040.png
# component 726: B50041.png
# component 727: B50042.png
# component 728: B50043.png
# component 729: B50044.png
# component 730: B50045.png
# component 731: B50046.png
# component 732: B50047.png
# component 733: B50048.png
# component 734: B50049.png
# component 735: B50050.png
# component 736: B50051.png
# component 737: B50052.png
# component 738: B50053.png
# component 739: B50054.png
# component 740: B50055.png
# component 741: B50056.png
# component 742: B50057.png
# component 743: B50058.png
# component 744: B50059.png
# component 745: B50060.png
# component 746: B50061.png
# component 747: B50062.png
# component 748: B50063.png
# component 749: B50064.png
# component 750: B50065.png
# component 751: B50066.png
# component 752: B50067.png
# component 753: B50068.png
# component 754: B50069.png
# component 755: B50070.png
# component 756: B50071.png
# component 757: B50072.png
# component 758: B50073.png
# component 759: B50074.png
# component 760: B50075.png
# component 761: B50076.png
# component 762: B50077.png
# component 763: B50078.png
# component 764: B50079.png
# component 765: B50080.png
# component 766: B50081.png
# component 767: B50082.png
# component 768: B50083.png
# component 769: B50084.png
# component 770: B50085.png
# component 771: B50086.png
# component 772: B50087.png
# component 773: B50088.png
# component 774: B50089.png
# component 775: B50090.png
# component 776: B50091.png
# component 777: B50092.png
# component 778: B50093.png
# component 779: B50094.png
# component 780: B50095.png
# component 781: B50096.png
# component 782: B50097.png
# component 783: B50098.png
# component 784: B50099.png
# component 785: B50100.png
# component 786: B50101.png
# component 787: B50102.png
# component 788: B50103.png
# component 789: B50104.png
# component 790: B50105.png
# component 791: B50106.png
# component 792: B50107.png
# component 793: B50108.png
# component 794: B50109.png
# component 795: B50110.png
# component 796: B50111.png
# component 797: B50112.png
# component 798: B50113.png
# component 799: B50114.png
# component 800: B50115.png
# component 801: B50116.png
# component 802: B50117.png
# component 803: B50118.png
# component 804: B50119.png
# component 805: B50120.png
# component 806: B50121.png
# component 807: B50122.png
# component 808: B50123.png
# component 809: B50124.png
# component 810: B50125.png
# component 811: B50126.png
# component 812: B50127.png
# component 813: B50128.png
# component 814: B50129.png
# component 815: B50130.png
# component 816: B50131.png
# component 817: B50132.png
# component 818: B50133.png
# component 819: B50134.png
# component 820: B50135.png
# component 821: B50136.png
# component 822: B50137.png
# component 823: B50138.png
# component 824: B50139.png
# component 825: B50140.png
# component 826: B50141.png
# component 827: B50142.png
# component 828: B50143.png
# component 829: B50144.png
# component 830: B50145.png
# component 831: B50146.png
# component 832: B50147.png
# component 833: B50148.png
# component 834: B50149.png
# component 835: B50150.png
# component 836: B50151.png
# component 837: B50152.png
# component 838: B50153.png
# component 839: B50154.png
# component 840: B50155.png
# component 841: B50156.png
# component 842: B50157.png
# component 843: B50158.png
# component 844: B50159.png
# component 845: B50160.png
# component 846: B50161.png
# component 847: B50162.png
# component 848: B50163.png
# component 849: B50164.png
# component 850: B50165.png
# component 851: B50166.png
# component 852: B50167.png
# component 853: B50168.png
# component 854: B50169.png
# component 855: B50170.png
# component 856: B50171.png
# component 857: B50172.png
# component 858: B50173.png
# component 859: B50174.png
# component 860: B50175.png
# component 861: B50176.png
# component 862: B50177.png
# component 863: B50178.png
# component 864: B50179.png
# component 865: B50180.png
# component 866: B50181.png
# component 867: B50182.png
# component 868: B50183.png
# component 869: B50184.png
# component 870: B50185.png
# component 871: B50186.png
# component 872: B50187.png
# component 873: B50188.png
# component 874: B50189.png
# component 875: B50190.png
# component 876: B50191.png
# component 877: B50192.png
# component 878: B50193.png
# component 879: B50194.png
# component 880: B50195.png
# component 881: B50196.png
# component 882: B50197.png
# component 883: B50198.png
# component 884: B50199.png
# component 885: B50200.png
# component 886: B50201.png
# component 887: B50202.png
# component 888: B50203.png
# component 889: B50204.png
# component 890: B50205.png
# component 891: B50206.png
# component 892: B50207.png
# component 893: B50208.png
# component 894: B50209.png
# component 895: B50210.png
# component 896: B50211.png
# component 897: B50212.png
# component 898: B50213.png
# component 899: B50214.png
# component 900: B50215.png
# component 901: B50216.png
# component 902: B50217.png
# component 903: B50218.png
# component 904: B50219.png
# component 905: B50220.png
# component 906: B50221.png
# component 907: B50222.png
# component 908: B50223.png
# component 909: B50224.png
# component 910: B50225.png
# component 911: B50226.png
# component 912: B50227.png
# component 913: B50228.png
# component 914: B50229.png
# component 915: B50230.png
# component 916: B50231.png
# component 917: B50232.png
# component 918: B50233.png
# component 919: B50234.png
# component 920: B50235.png
# component 921: B50236.png
# component 922: B50237.png
# component 923: B50238.png
# component 924: B50239.png
# component 925: B50240.png
# component 926: B50241.png
# component 927: B50242.png
# component 928: B50243.png
# component 929: B50244.png
# component 930: B50245.png
# component 931: B50246.png
# component 932: B50247.png
# component 933: B50248.png
# component 934: B50249.png
# component 935: B50250.png
# component 936: B50251.png
# component 937: B50252.png
# component 938: B50253.png
# component 939: B50254.png
# component 940: B50255.png
# component 941: B50256.png
# component 942: B50257.png
# component 943: B50258.png
# component 944: B50259.png
# component 945: B50260.png
# component 946: B50261.png
# component 947: B50262.png
# component 948: B50263.png
# component 949: B50264.png
# component 950: B50265.png
# component 951: B50266.png
# component 952: B50267.png
# component 953: B50268.png
# component 954: B50269.png
# component 955: B50270.png
# component 956: B50271.png
# component 957: B50272.png
# component 958: B50273.png
# component 959: B50274.png
# component 960: B50275.png
# component 961: B50276.png
# component 962: B50277.png
# component 963: B50278.png
# component 964: B50279.png
# component 965: B50280.png
# component 966: B50281.png
# component 967: B50282.png
# component 968: B50283.png
# component 969: B50284.png
# component 970: B50285.png
# component 971: B50286.png
# component 972: B50287.png
# component 973: B50288.png
# component 974: B50289.png
# component 975: B50290.png
# component 976: B50291.png
# component 977: B50292.png
# component 978: B50293.png
# component 979: B50294.png
# component 980: B50295.png
# component 981: B50296.png
# component 982: B50297.png
# component 983: B50298.png
# component 984: B50299.png
# component 985: B50300.png
# component 986: B50301.png
# component 987: B50302.png
# component 988: B50303.png
# component 989: B50304.png
# component 990: B50305.png
# component 991: B50306.png
# component 992: B50307.png
# component 993: B50308.png
# component 994: B50309.png
# component 995: B50310.png
# component 996: B50311.png
# component 997: B50312.png
# component 998: B50313.png
# component 999: B50314.png
# component 1000: B50315.png
# component 1001: B50316.png
# component 1002: B50317.png
# component 1003: B50318.png
# component 1004: B50319.png

# %%
model_params = sum(param.numel() for param in model.parameters())
trainable_params = sum(param.numel() for param in model.parameters() if param.requires_grad)

print(f'model_params:{model_params}, trainable_params:{trainable_params}')
# Out:
# model_params:263140864, trainable_params:263140864
